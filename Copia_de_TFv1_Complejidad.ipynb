# %% [markdown]
# <a href="https://colab.research.google.com/github/JeffersonEspinalA/Prueba/blob/main/Copia_de_TFv1_Complejidad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import random

# %%
# %%file Calles.txt
# Av.1
# C.2
# C.3
# C.4
# C.5
# C.6
# Av.7
# C.8
# C.9
# C.10
# C.11
# C.12
# Calle_14
# C.15
# C.16
# C.17
# C.18
# Av.19
# C.20
# C.21
# C.22
# C.23
# C.24
# Av.25
# C.26
# C.27
# Calle_28
# C.29
# C.30
# Av.31
# C.132
# C.133
# C.134
# C.135
# C.136
# Av.137
# C.138
# C.139
# C.140
# C.141
# C.142
# C.143
# C.521
# C.522
# C.523
# C.524
# C.525
# C.526
# C.527
# C.528
# C.529
# C.530
# C.531
# Av.32
# C.33
# C.34
# C.35
# C.36
# C.37
# Av.38
# Calle_39
# C.40
# C.41
# Calle_42
# C.43
# Av.44
# C.45
# C.46
# C.47
# C.48
# C.49
# C.50
# Av.51
# Av.53
# C.54
# C.55
# C.56
# C.57
# C.58
# C.59
# Av.60
# C.61
# C.62
# C.63
# C.64
# C.65
# Out:
# Writing Calles.txt

# %%
# %%file Intersecciones_con_coordenadas.txt
# 0 Av.1 C.521 -34.885116 -57.976523
# 1 Av.1 C.522 -34.887932 -57.974166
# 2 Av.1 C.528 -34.891870 -57.967053
# 3 Av.1 C.529 -34.892609 -57.966013
# 4 Av.1 C.530 -34.893386 -57.964961
# 5 Av.1 C.531 -34.894156 -57.963899
# 6 Av.1 Av.32 -34.894975 -57.962831
# 7 Av.1 C.33 -34.895855 -57.961672
# 8 Av.1 C.34 -34.896700 -57.960551
# 9 Av.1 C.35 -34.897535 -57.959387
# 10 Av.1 C.36 -34.898376 -57.958293
# 11 Av.1 C.37 -34.899199 -57.957182
# 12 Av.1 Calle_39 -34.900923 -57.954865
# 13 Av.1 C.40 -34.901799 -57.953728
# 14 Av.1 C.41 -34.902535 -57.952560
# 15 Av.1 Calle_42 -34.903410 -57.951425
# 16 Av.1 C.43 -34.904207 -57.950321
# 17 Av.1 Av.44 -34.905021 -57.949226
# 18 Av.1 C.45 -34.905919 -57.947912
# 19 Av.1 C.46 -34.906706 -57.946834
# 20 Av.1 C.47 -34.907454 -57.945938
# 21 Av.1 C.48 -34.908123 -57.945123
# 22 Av.1 C.49 -34.908721 -57.944345
# 23 Av.1 C.50 -34.909192 -57.943578
# 24 Av.1 Av.51 -34.909698 -57.942918
# 25 Av.1 Av.53 -34.910582 -57.941663
# 26 Av.1 C.54 -34.911149 -57.941008
# 27 Av.1 C.55 -34.911673 -57.940308
# 28 Av.1 C.56 -34.912278 -57.939462
# 29 Av.1 C.57 -34.912903 -57.938577
# 30 Av.1 C.58 -34.913625 -57.937654
# 31 Av.1 C.59 -34.914425 -57.936533
# 32 Av.1 Av.60 -34.915252 -57.935428
# 33 Av.1 C.61 -34.916151 -57.934237
# 34 Av.1 C.62 -34.916991 -57.933132
# 35 Av.1 C.63 -34.917831 -57.932005
# 36 Av.1 C.64 -34.918645 -57.930889
# 37 Av.1 C.65 -34.919467 -57.929838
# 38 C.2 C.521 -34.886530 -57.976181
# 39 C.2 C.522 -34.887381 -57.975111
# 40 C.2 C.528 -34.892515 -57.967753
# 41 C.2 C.529 -34.893298 -57.966690
# 42 C.2 C.530 -34.894055 -57.965693
# 43 C.2 C.531 -34.894830 -57.964655
# 44 C.2 Av.32 -34.895815 -57.963721
# 45 C.2 C.33 -34.896726 -57.962654
# 46 C.2 C.34 -34.897609 -57.961552
# 47 C.2 C.35 -34.898454 -57.960422
# 48 C.2 C.36 -34.899269 -57.959258
# 49 C.2 C.37 -34.900106 -57.958161
# 50 C.2 Av.38 -34.900942 -57.957064
# 51 C.2 Calle_39 -34.901853 -57.955814
# 52 C.2 C.40 -34.902667 -57.954725
# 53 C.2 C.41 -34.903514 -57.953587
# 54 C.2 Calle_42 -34.904354 -57.952458
# 55 C.2 C.43 -34.905177 -57.951340
# 56 C.2 Av.44 -34.906094 -57.950192
# 57 C.2 C.45 -34.906831 -57.949036
# 58 C.2 C.46 -34.907768 -57.947974
# 59 C.2 C.47 -34.908364 -57.947008
# 60 C.2 C.48 -34.909051 -57.946147
# 61 C.2 C.49 -34.909614 -57.945318
# 62 C.2 C.50 -34.910122 -57.944623
# 63 C.2 Av.51 -34.910659 -57.943918
# 64 C.2 Av.53 -34.911556 -57.942746
# 65 C.2 C.54 -34.912077 -57.942019
# 66 C.2 C.55 -34.912634 -57.941270
# 67 C.2 C.56 -34.913219 -57.940501
# 68 C.2 C.57 -34.913870 -57.939607
# 69 C.2 C.58 -34.914541 -57.938706
# 70 C.2 C.59 -34.915365 -57.937636
# 71 C.2 Av.60 -34.916221 -57.936485
# 72 C.2 C.61 -34.917103 -57.935313
# 73 C.2 C.62 -34.917915 -57.934211
# 74 C.2 C.63 -34.918774 -57.933047
# 75 C.2 C.64 -34.919560 -57.931920
# 76 C.2 C.65 -34.920393 -57.931000
# 77 C.3 C.521 -34.887415 -57.977214
# 78 C.3 C.522 -34.888269 -57.976119
# 79 C.3 C.523 -34.889202 -57.975079
# 80 C.3 C.524 -34.890038 -57.973984
# 81 C.3 C.525 -34.890865 -57.972858
# 82 C.3 C.526 -34.891684 -57.971774
# 83 C.3 C.527 -34.892564 -57.970519
# 84 C.3 C.528 -34.893435 -57.969403
# 85 C.3 C.529 -34.894658 -57.968191
# 86 C.3 C.530 -34.895406 -57.967193
# 87 C.3 C.531 -34.896202 -57.966142
# 88 C.3 Av.32 -34.896849 -57.964790
# 89 C.3 C.33 -34.897685 -57.963669
# 90 C.3 C.34 -34.898543 -57.962553
# 91 C.3 C.35 -34.899370 -57.961432
# 92 C.3 C.36 -34.900189 -57.960337
# 93 C.3 C.37 -34.901020 -57.959162
# 94 C.3 Av.38 -34.901882 -57.957998
# 95 C.3 Calle_39 -34.902797 -57.956807
# 96 C.3 C.40 -34.903567 -57.955751
# 97 C.3 C.41 -34.904416 -57.954613
# 98 C.3 Calle_42 -34.905261 -57.953487
# 99 C.3 C.43 -34.906121 -57.952355
# 100 C.3 Av.44 -34.906953 -57.951220
# 101 C.3 C.45 -34.907806 -57.950032
# 102 C.3 C.46 -34.908616 -57.948957
# 103 C.3 C.47 -34.909358 -57.948079
# 104 C.3 C.48 -34.910009 -57.947172
# 105 C.3 C.49 -34.910524 -57.946357
# 106 C.3 C.50 -34.911043 -57.945663
# 107 C.3 Av.51 -34.911584 -57.944979
# 108 C.3 Av.53 -34.912495 -57.943796
# 109 C.3 C.54 -34.913042 -57.943034
# 110 C.3 C.55 -34.913570 -57.942326
# 111 C.3 C.56 -34.914168 -57.941503
# 112 C.3 C.57 -34.914806 -57.940636
# 113 C.3 C.58 -34.915530 -57.939711
# 114 C.3 C.59 -34.916300 -57.938659
# 115 C.3 Av.60 -34.917127 -57.937558
# 116 C.3 C.61 -34.918053 -57.936309
# 117 C.3 C.62 -34.918883 -57.935211
# 118 C.3 C.63 -34.919695 -57.934042
# 119 C.3 C.64 -34.920598 -57.932950
# 120 C.3 C.65 -34.921265 -57.931834
# 121 C.4 C.521 -34.888423 -57.978333
# 122 C.4 C.522 -34.889278 -57.977184
# 123 C.4 C.523 -34.889558 -57.976805
# 124 C.4 C.524 -34.890963 -57.974954
# 125 C.4 C.525 -34.891773 -57.973830
# 126 C.4 C.526 -34.892617 -57.972720
# 127 C.4 C.527 -34.893539 -57.971510
# 128 C.4 C.528 -34.894369 -57.970394
# 129 C.4 C.529 -34.895396 -57.968999
# 130 C.4 C.530 -34.896173 -57.967993
# 131 C.4 C.531 -34.896934 -57.966934
# 132 C.4 Av.32 -34.897770 -57.965853
# 133 C.4 C.33 -34.898609 -57.964688
# 134 C.4 C.34 -34.899431 -57.963583
# 135 C.4 C.35 -34.900292 -57.962441
# 136 C.4 C.36 -34.901134 -57.961298
# 137 C.4 C.37 -34.901950 -57.960188
# 138 C.4 Av.38 -34.902806 -57.959064
# 139 C.4 Calle_39 -34.903710 -57.957872
# 140 C.4 C.40 -34.904497 -57.956770
# 141 C.4 C.41 -34.905241 -57.955657
# 142 C.4 Calle_42 -34.906162 -57.954460
# 143 C.4 C.43 -34.907020 -57.953363
# 144 C.4 Av.44 -34.907880 -57.952230
# 145 C.4 C.45 -34.908778 -57.951055
# 146 C.4 C.46 -34.909531 -57.950011
# 147 C.4 C.47 -34.910232 -57.949064
# 148 C.4 C.48 -34.910920 -57.948190
# 149 C.4 C.49 -34.911522 -57.947382
# 150 C.4 C.50 -34.912014 -57.946666
# 151 C.4 Av.51 -34.912518 -57.945944
# 152 C.4 Av.53 -34.913415 -57.944756
# 153 C.4 C.54 -34.913954 -57.944067
# 154 C.4 C.55 -34.914473 -57.943345
# 155 C.4 C.56 -34.915061 -57.942557
# 156 C.4 C.57 -34.915764 -57.941706
# 157 C.4 C.58 -34.916448 -57.940704
# 158 C.4 C.59 -34.917212 -57.939651
# 159 C.4 Av.60 -34.918034 -57.938584
# 160 C.4 C.61 -34.918959 -57.937339
# 161 C.4 C.62 -34.919827 -57.936204
# 162 C.4 C.63 -34.920664 -57.935082
# 163 C.4 C.64 -34.921436 -57.934003
# 164 C.4 C.65 -34.922254 -57.932842
# 165 C.5 C.521 -34.889374 -57.979322
# 166 C.5 C.522 -34.890210 -57.978244
# 167 C.5 C.523 -34.891054 -57.977101
# 168 C.5 C.524 -34.891891 -57.975969
# 169 C.5 C.525 -34.892718 -57.974843
# 170 C.5 C.526 -34.893541 -57.973748
# 171 C.5 C.527 -34.894447 -57.972514
# 172 C.5 C.528 -34.895261 -57.971404
# 173 C.5 C.529 -34.896744 -57.970508
# 174 C.5 C.530 -34.897509 -57.969484
# 175 C.5 C.531 -34.898284 -57.968459
# 176 C.5 Av.32 -34.898706 -57.967880
# 177 C.5 C.33 -34.899560 -57.965718
# 178 C.5 C.34 -34.900378 -57.964597
# 179 C.5 C.35 -34.901218 -57.963452
# 180 C.5 C.36 -34.902040 -57.962331
# 181 C.5 C.37 -34.902938 -57.961253
# 182 C.5 Av.38 -34.903721 -57.960116
# 183 C.5 Calle_39 -34.904632 -57.958898
# 184 C.5 C.40 -34.905476 -57.957739
# 185 C.5 C.41 -34.906259 -57.956629
# 186 C.5 Calle_42 -34.907082 -57.955524
# 187 C.5 C.43 -34.907911 -57.954430
# 188 C.5 Av.44 -34.908804 -57.953193
# 189 C.5 C.45 -34.909703 -57.952052
# 190 C.5 C.46 -34.910464 -57.951022
# 191 C.5 C.47 -34.911181 -57.950072
# 192 C.5 C.48 -34.911831 -57.949167
# 193 C.5 C.49 -34.912411 -57.948379
# 194 C.5 C.50 -34.912948 -57.947612
# 195 C.5 Av.51 -34.913432 -57.947027
# 196 C.5 Av.53 -34.914348 -57.945825
# 197 C.5 C.54 -34.914871 -57.945100
# 198 C.5 C.55 -34.915412 -57.944365
# 199 C.5 C.56 -34.915989 -57.943582
# 200 C.5 C.57 -34.916670 -57.942660
# 201 C.5 C.58 -34.917361 -57.941737
# 202 C.5 C.59 -34.918153 -57.940648
# 203 C.5 Av.60 -34.918936 -57.939554
# 204 C.5 C.61 -34.919912 -57.938373
# 205 C.5 C.62 -34.920696 -57.937262
# 206 C.5 C.63 -34.921501 -57.936125
# 207 C.5 C.64 -34.922356 -57.935001
# 208 C.5 C.65 -34.923191 -57.933848
# 209 C.6 C.521 -34.890297 -57.980339
# 210 C.6 C.522 -34.891124 -57.979218
# 211 C.6 C.523 -34.891982 -57.978108
# 212 C.6 C.524 -34.892823 -57.976981
# 213 C.6 C.525 -34.893641 -57.975865
# 214 C.6 C.526 -34.894486 -57.974723
# 215 C.6 C.527 -34.895361 -57.973516
# 216 C.6 C.528 -34.896465 -57.972652
# 217 C.6 C.529 -34.897264 -57.971541
# 218 C.6 C.530 -34.898124 -57.970399
# 219 C.6 C.531 -34.898971 -57.969283
# 220 C.6 Av.32 -34.899413 -57.968650
# 221 C.6 C.33 -34.900467 -57.966700
# 222 C.6 C.34 -34.901289 -57.965587
# 223 C.6 C.35 -34.902125 -57.964423
# 224 C.6 C.36 -34.902962 -57.963329
# 225 C.6 C.37 -34.903793 -57.962225
# 226 C.6 Av.38 -34.904639 -57.961109
# 227 C.6 Calle_39 -34.905526 -57.959924
# 228 C.6 C.40 -34.906387 -57.958729
# 229 C.6 C.41 -34.907228 -57.957618
# 230 C.6 Calle_42 -34.908012 -57.956549
# 231 C.6 C.43 -34.908889 -57.955421
# 232 C.6 Av.44 -34.909709 -57.954265
# 233 C.6 C.45 -34.910595 -57.953098
# 234 C.6 C.46 -34.911467 -57.952045
# 235 C.6 C.47 -34.912096 -57.951085
# 236 C.6 C.48 -34.912754 -57.950189
# 237 C.6 C.49 -34.913288 -57.949446
# 238 C.6 C.50 -34.913884 -57.948679
# 239 C.6 Av.51 -34.914260 -57.948011
# 240 C.6 Av.53 -34.915252 -57.946779
# 241 C.6 C.54 -34.915821 -57.946108
# 242 C.6 C.55 -34.916305 -57.945395
# 243 C.6 C.56 -34.916941 -57.944602
# 244 C.6 C.57 -34.917611 -57.943680
# 245 C.6 C.58 -34.918278 -57.942773
# 246 C.6 C.59 -34.919079 -57.941668
# 247 C.6 Av.60 -34.919887 -57.940623
# 248 C.6 C.61 -34.920790 -57.939534
# 249 C.6 C.62 -34.921621 -57.938234
# 250 C.6 C.63 -34.922466 -57.937112
# 251 C.6 C.64 -34.923292 -57.936005
# 252 C.6 C.65 -34.924129 -57.934858
# 253 Av.7 C.521 -34.891327 -57.981469
# 254 Av.7 C.522 -34.892113 -57.980348
# 255 Av.7 C.523 -34.892979 -57.979205
# 256 Av.7 C.524 -34.893820 -57.978100
# 257 Av.7 C.525 -34.894643 -57.976985
# 258 Av.7 C.526 -34.895492 -57.975847
# 259 Av.7 C.527 -34.896794 -57.974388
# 260 Av.7 C.528 -34.897423 -57.973170
# 261 Av.7 C.529 -34.898092 -57.972436
# 262 Av.7 C.530 -34.898888 -57.971266
# 263 Av.7 C.531 -34.899742 -57.970177
# 264 Av.7 Av.32 -34.900213 -57.969507
# 265 Av.7 C.33 -34.901483 -57.967825
# 266 Av.7 C.34 -34.902320 -57.966694
# 267 Av.7 C.35 -34.903160 -57.965571
# 268 Av.7 C.36 -34.903974 -57.964461
# 269 Av.7 C.37 -34.904819 -57.963331
# 270 Av.7 Calle_39 -34.906466 -57.960947
# 271 Av.7 C.40 -34.907429 -57.959891
# 272 Av.7 C.41 -34.908225 -57.958748
# 273 Av.7 Calle_42 -34.909071 -57.957631
# 274 Av.7 C.43 -34.909898 -57.956526
# 275 Av.7 Av.44 -34.910231 -57.956027
# 276 Av.7 C.45 -34.911665 -57.954193
# 277 Av.7 C.46 -34.912418 -57.953082
# 278 Av.7 C.47 -34.913121 -57.952160
# 279 Av.7 C.48 -34.913764 -57.951269
# 280 Av.7 C.49 -34.914349 -57.950464
# 281 Av.7 C.50 -34.914899 -57.949821
# 282 Av.7 Av.51 -34.915430 -57.949101
# 283 Av.7 Av.53 -34.916278 -57.947921
# 284 Av.7 C.54 -34.916705 -57.947164
# 285 Av.7 C.55 -34.917264 -57.946456
# 286 Av.7 C.56 -34.917906 -57.945641
# 287 Av.7 C.57 -34.918530 -57.944801
# 288 Av.7 C.58 -34.919304 -57.943868
# 289 Av.7 C.59 -34.920050 -57.942796
# 290 Av.7 C.61 -34.921793 -57.940386
# 291 Av.7 C.62 -34.922625 -57.939340
# 292 Av.7 C.63 -34.923478 -57.938235
# 293 Av.7 C.64 -34.924283 -57.937071
# 294 Av.7 C.65 -34.925145 -57.935996
# 295 C.8 C.521 -34.892246 -57.982458
# 296 C.8 C.522 -34.893055 -57.981369
# 297 C.8 C.523 -34.893880 -57.980239
# 298 C.8 C.524 -34.894721 -57.979128
# 299 C.8 C.525 -34.895559 -57.977962
# 300 C.8 C.526 -34.896408 -57.976857
# 301 C.8 C.528 -34.898181 -57.974518
# 302 C.8 C.529 -34.898999 -57.973386
# 303 C.8 C.530 -34.899804 -57.972280
# 304 C.8 C.531 -34.900632 -57.971175
# 305 C.8 Av.32 -34.901512 -57.969947
# 306 C.8 C.33 -34.902368 -57.968796
# 307 C.8 C.34 -34.903232 -57.967710
# 308 C.8 C.35 -34.904082 -57.966573
# 309 C.8 C.36 -34.904895 -57.965461
# 310 C.8 C.37 -34.905720 -57.964292
# 311 C.8 Av.38 -34.906557 -57.963248
# 312 C.8 Calle_39 -34.907466 -57.962020
# 313 C.8 C.40 -34.908307 -57.960890
# 314 C.8 C.41 -34.909135 -57.959776
# 315 C.8 Calle_42 -34.910002 -57.958645
# 316 C.8 C.43 -34.910834 -57.957534
# 317 C.8 Av.44 -34.911650 -57.956388
# 318 C.8 C.45 -34.912478 -57.955271
# 319 C.8 C.46 -34.913284 -57.954158
# 320 C.8 C.47 -34.914019 -57.953199
# 321 C.8 C.48 -34.914734 -57.952323
# 322 C.8 C.49 -34.915280 -57.951503
# 323 C.8 C.50 -34.915843 -57.950764
# 324 C.8 Av.51 -34.916370 -57.950036
# 325 C.8 Av.53 -34.917197 -57.948922
# 326 C.8 C.54 -34.917702 -57.948209
# 327 C.8 C.55 -34.918241 -57.947519
# 328 C.8 C.56 -34.918911 -57.946585
# 329 C.8 C.57 -34.919506 -57.945800
# 330 C.8 C.58 -34.920225 -57.944845
# 331 C.8 C.59 -34.920989 -57.943877
# 332 C.8 Av.60 -34.921904 -57.942584
# 333 C.8 C.61 -34.922736 -57.941455
# 334 C.8 C.62 -34.923574 -57.940353
# 335 C.8 C.63 -34.924396 -57.939220
# 336 C.8 C.64 -34.925240 -57.938114
# 337 C.8 C.65 -34.926074 -57.936964
# 338 C.9 C.521 -34.893124 -57.983469
# 339 C.9 C.522 -34.893961 -57.982351
# 340 C.9 C.523 -34.894815 -57.981242
# 341 C.9 C.524 -34.895655 -57.980119
# 342 C.9 C.525 -34.896480 -57.978987
# 343 C.9 C.527 -34.898243 -57.976635
# 344 C.9 C.528 -34.899062 -57.975534
# 345 C.9 C.529 -34.899909 -57.974429
# 346 C.9 C.530 -34.900741 -57.973300
# 347 C.9 C.531 -34.901573 -57.972200
# 348 C.9 Av.32 -34.902065 -57.971470
# 349 C.9 C.33 -34.903307 -57.969852
# 350 C.9 C.34 -34.904167 -57.968720
# 351 C.9 C.35 -34.904984 -57.967605
# 352 C.9 C.36 -34.905807 -57.966468
# 353 C.9 C.37 -34.906632 -57.965381
# 354 C.9 Av.38 -34.907453 -57.964241
# 355 C.9 Calle_39 -34.908402 -57.963022
# 356 C.9 C.40 -34.909246 -57.961897
# 357 C.9 C.41 -34.910066 -57.960768
# 358 C.9 Calle_42 -34.910923 -57.959658
# 359 C.9 C.43 -34.911751 -57.958525
# 360 C.9 Av.44 -34.912649 -57.957310
# 361 C.9 C.45 -34.913462 -57.956178
# 362 C.9 C.46 -34.914230 -57.955155
# 363 C.9 C.47 -34.914941 -57.954194
# 364 C.9 C.48 -34.915629 -57.953319
# 365 C.9 C.49 -34.916234 -57.952494
# 366 C.9 C.50 -34.916744 -57.951833
# 367 C.9 Av.51 -34.917311 -57.951052
# 368 C.9 Av.53 -34.918106 -57.949950
# 369 C.9 C.54 -34.918696 -57.949208
# 370 C.9 C.55 -34.919200 -57.948504
# 371 C.9 C.56 -34.919814 -57.947681
# 372 C.9 C.57 -34.920431 -57.946803
# 373 C.9 C.58 -34.921033 -57.946005
# 374 C.9 C.59 -34.921801 -57.944813
# 375 C.9 Av.60 -34.922752 -57.943700
# 376 C.9 C.61 -34.923678 -57.942464
# 377 C.9 C.62 -34.924488 -57.941368
# 378 C.9 C.63 -34.925341 -57.940237
# 379 C.9 C.64 -34.926171 -57.939123
# 380 C.9 C.65 -34.927000 -57.937981
# 381 C.10 C.521 -34.894081 -57.984502
# 382 C.10 C.522 -34.894921 -57.983397
# 383 C.10 C.523 -34.895757 -57.982233
# 384 C.10 C.524 -34.896580 -57.981122
# 385 C.10 C.526 -34.898243 -57.978869
# 386 C.10 C.527 -34.899154 -57.977646
# 387 C.10 C.528 -34.900025 -57.976525
# 388 C.10 C.529 -34.900828 -57.975437
# 389 C.10 C.530 -34.901650 -57.974294
# 390 C.10 C.531 -34.902478 -57.973205
# 391 C.10 Av.32 -34.903383 -57.971998
# 392 C.10 C.33 -34.904250 -57.970860
# 393 C.10 C.34 -34.905090 -57.969712
# 394 C.10 C.35 -34.905917 -57.968602
# 395 C.10 C.36 -34.906762 -57.967502
# 396 C.10 C.37 -34.907563 -57.966376
# 397 C.10 Av.38 -34.908394 -57.965249
# 398 C.10 Calle_39 -34.909322 -57.964015
# 399 C.10 C.40 -34.910147 -57.962875
# 400 C.10 C.41 -34.910978 -57.961775
# 401 C.10 Calle_42 -34.911845 -57.960648
# 402 C.10 C.43 -34.912659 -57.959538
# 403 C.10 Av.44 -34.913565 -57.958347
# 404 C.10 C.45 -34.914357 -57.957184
# 405 C.10 C.46 -34.915127 -57.956181
# 406 C.10 C.47 -34.915844 -57.955253
# 407 C.10 C.48 -34.916425 -57.954341
# 408 C.10 C.49 -34.917128 -57.953541
# 409 C.10 C.50 -34.917639 -57.952801
# 410 C.10 Av.51 -34.918219 -57.952088
# 411 C.10 Av.53 -34.919033 -57.950972
# 412 C.10 C.54 -34.919574 -57.950210
# 413 C.10 C.55 -34.920085 -57.949553
# 414 C.10 C.56 -34.920711 -57.948715
# 415 C.10 C.57 -34.921359 -57.947870
# 416 C.10 C.58 -34.922075 -57.946897
# 417 C.10 C.59 -34.922872 -57.945842
# 418 C.10 Av.60 -34.923747 -57.944620
# 419 C.10 C.61 -34.924600 -57.943478
# 420 C.10 C.62 -34.925437 -57.942369
# 421 C.10 C.63 -34.926243 -57.941261
# 422 C.10 C.64 -34.927085 -57.940109
# 423 C.10 C.65 -34.927921 -57.939014
# 424 C.11 C.521 -34.894895 -57.985381
# 425 C.11 C.522 -34.895724 -57.984271
# 426 C.11 C.523 -34.896534 -57.983117
# 427 C.11 C.525 -34.898284 -57.981017
# 428 C.11 C.526 -34.899268 -57.979783
# 429 C.11 C.527 -34.900095 -57.978666
# 430 C.11 C.528 -34.900898 -57.977554
# 431 C.11 C.529 -34.901772 -57.976439
# 432 C.11 C.530 -34.902585 -57.975314
# 433 C.11 C.531 -34.903253 -57.974423
# 434 C.11 Av.32 -34.903925 -57.973522
# 435 C.11 C.33 -34.905155 -57.971867
# 436 C.11 C.34 -34.905984 -57.970739
# 437 C.11 C.35 -34.906857 -57.969624
# 438 C.11 C.36 -34.907663 -57.968487
# 439 C.11 C.37 -34.908494 -57.967394
# 440 C.11 Av.38 -34.909328 -57.966280
# 441 C.11 Calle_39 -34.910255 -57.965035
# 442 C.11 C.40 -34.911086 -57.963920
# 443 C.11 C.41 -34.911932 -57.962790
# 444 C.11 Calle_42 -34.912760 -57.961656
# 445 C.11 C.43 -34.913590 -57.960558
# 446 C.11 Av.44 -34.914439 -57.959401
# 447 C.11 C.45 -34.915299 -57.958213
# 448 C.11 C.46 -34.916099 -57.957158
# 449 C.11 C.47 -34.916828 -57.956211
# 450 C.11 C.48 -34.917372 -57.955336
# 451 C.11 C.49 -34.918060 -57.954526
# 452 C.11 C.50 -34.918576 -57.953808
# 453 C.11 Av.51 -34.919134 -57.953092
# 454 C.11 Av.53 -34.919951 -57.952001
# 455 C.11 C.54 -34.920497 -57.951272
# 456 C.11 C.55 -34.921002 -57.950578
# 457 C.11 C.56 -34.921671 -57.949749
# 458 C.11 C.57 -34.922348 -57.948874
# 459 C.11 C.58 -34.922994 -57.947915
# 460 C.11 C.59 -34.923802 -57.946862
# 461 C.11 Av.60 -34.924587 -57.945724
# 462 C.11 C.61 -34.925532 -57.944473
# 463 C.11 C.62 -34.926334 -57.943404
# 464 C.11 C.63 -34.927148 -57.942278
# 465 C.11 C.64 -34.928003 -57.941095
# 466 C.11 C.65 -34.928843 -57.939999
# 467 C.12 C.521 -34.895905 -57.986513
# 468 C.12 C.522 -34.896759 -57.985413
# 469 C.12 C.525 -34.899301 -57.982017
# 470 C.12 C.526 -34.900110 -57.980918
# 471 C.12 C.527 -34.901009 -57.979691
# 472 C.12 C.528 -34.901851 -57.978565
# 473 C.12 C.529 -34.902684 -57.977463
# 474 C.12 C.530 -34.903513 -57.976310
# 475 C.12 C.531 -34.904167 -57.975426
# 476 C.12 Av.32 -34.904820 -57.974565
# 477 C.12 C.33 -34.906054 -57.972860
# 478 C.12 C.34 -34.906942 -57.971788
# 479 C.12 C.35 -34.907754 -57.970655
# 480 C.12 C.36 -34.908581 -57.969501
# 481 C.12 C.37 -34.909423 -57.968388
# 482 C.12 Av.38 -34.910234 -57.967268
# 483 C.12 Calle_39 -34.911168 -57.966035
# 484 C.12 C.40 -34.911963 -57.964886
# 485 C.12 C.41 -34.912837 -57.963775
# 486 C.12 Calle_42 -34.913667 -57.962680
# 487 C.12 C.43 -34.914498 -57.961563
# 488 C.12 Av.44 -34.915420 -57.960347
# 489 C.12 C.45 -34.916253 -57.959215
# 490 C.12 C.46 -34.916993 -57.958192
# 491 C.12 C.47 -34.917735 -57.957214
# 492 C.12 C.48 -34.918416 -57.956353
# 493 C.12 C.49 -34.919001 -57.955522
# 494 C.12 C.50 -34.919517 -57.954800
# 495 C.12 Av.51 -34.919999 -57.954168
# 496 C.12 Av.53 -34.920887 -57.953055
# 497 C.12 C.54 -34.921423 -57.952307
# 498 C.12 C.55 -34.921874 -57.951551
# 499 C.12 C.56 -34.922566 -57.950775
# 500 C.12 C.57 -34.923252 -57.949883
# 501 C.12 C.58 -34.923929 -57.948904
# 502 C.12 C.59 -34.924725 -57.947883
# 503 C.12 Av.60 -34.925529 -57.946744
# 504 C.12 C.61 -34.926413 -57.945525
# 505 C.12 C.62 -34.927261 -57.944385
# 506 C.12 C.63 -34.928068 -57.943275
# 507 C.12 C.64 -34.928925 -57.942165
# 508 C.12 C.65 -34.929772 -57.940979
# 509 Calle_14 C.521 -34.897887 -57.988601
# 510 Calle_14 C.522 -34.898699 -57.987517
# 511 Calle_14 C.523 -34.899529 -57.986390
# 512 Calle_14 C.524 -34.900308 -57.985427
# 513 Calle_14 C.525 -34.901367 -57.984009
# 514 Calle_14 C.526 -34.901986 -57.983307
# 515 Calle_14 C.527 -34.902755 -57.981590
# 516 Calle_14 C.529 -34.904809 -57.979416
# 517 Calle_14 C.530 -34.905427 -57.978539
# 518 Calle_14 C.531 -34.906004 -57.977812
# 519 Calle_14 Av.32 -34.906869 -57.976784
# 520 Calle_14 C.33 -34.908018 -57.974981
# 521 Calle_14 C.34 -34.908870 -57.973871
# 522 Calle_14 C.35 -34.909694 -57.972764
# 523 Calle_14 C.36 -34.910514 -57.971619
# 524 Calle_14 C.37 -34.911352 -57.970501
# 525 Calle_14 Av.38 -34.912187 -57.969406
# 526 Calle_14 Calle_39 -34.913019 -57.968044
# 527 Calle_14 C.40 -34.913967 -57.967040
# 528 Calle_14 C.41 -34.914772 -57.965919
# 529 Calle_14 Calle_42 -34.915616 -57.964787
# 530 Calle_14 C.43 -34.916483 -57.963704
# 531 Calle_14 Av.44 -34.917253 -57.962540
# 532 Calle_14 C.45 -34.918181 -57.961338
# 533 Calle_14 C.46 -34.918981 -57.960306
# 534 Calle_14 C.47 -34.919671 -57.959322
# 535 Calle_14 C.48 -34.920340 -57.958447
# 536 Calle_14 C.49 -34.920895 -57.957657
# 537 Calle_14 C.50 -34.921421 -57.956903
# 538 Calle_14 Av.51 -34.921882 -57.956117
# 539 Calle_14 Av.53 -34.922616 -57.954938
# 540 Calle_14 C.54 -34.923388 -57.954327
# 541 Calle_14 C.55 -34.923825 -57.953655
# 542 Calle_14 C.56 -34.924468 -57.952762
# 543 Calle_14 C.57 -34.925131 -57.951900
# 544 Calle_14 C.58 -34.925758 -57.951036
# 545 Calle_14 C.59 -34.926643 -57.949966
# 546 Calle_14 Av.60 -34.927441 -57.948851
# 547 Calle_14 C.61 -34.928349 -57.947633
# 548 Calle_14 C.62 -34.929176 -57.946516
# 549 Calle_14 C.63 -34.930036 -57.945368
# 550 Calle_14 C.64 -34.930855 -57.944241
# 551 Calle_14 C.65 -34.931703 -57.943145
# 552 C.15 C.521 -34.898771 -57.989624
# 553 C.15 C.522 -34.899600 -57.988502
# 554 C.15 C.523 -34.900449 -57.987403
# 555 C.15 C.524 -34.901302 -57.986276
# 556 C.15 C.525 -34.902142 -57.985155
# 557 C.15 C.526 -34.903045 -57.983882
# 558 C.15 C.527 -34.903874 -57.982813
# 559 C.15 C.528 -34.904709 -57.981697
# 560 C.15 C.529 -34.905541 -57.980597
# 561 C.15 C.530 -34.906389 -57.979458
# 562 C.15 C.531 -34.907057 -57.978578
# 563 C.15 Av.32 -34.907625 -57.977687
# 564 C.15 C.33 -34.908932 -57.975987
# 565 C.15 C.34 -34.909770 -57.974876
# 566 C.15 C.35 -34.910588 -57.973766
# 567 C.15 C.36 -34.911420 -57.972623
# 568 C.15 C.37 -34.912256 -57.971509
# 569 C.15 Av.38 -34.913118 -57.970409
# 570 C.15 Calle_39 -34.914038 -57.969154
# 571 C.15 C.40 -34.914849 -57.968069
# 572 C.15 C.41 -34.915714 -57.966940
# 573 C.15 Calle_42 -34.916514 -57.965792
# 574 C.15 C.43 -34.917355 -57.964703
# 575 C.15 Av.44 -34.918256 -57.963501
# 576 C.15 C.45 -34.919096 -57.962358
# 577 C.15 C.46 -34.919853 -57.961296
# 578 C.15 C.47 -34.920596 -57.960363
# 579 C.15 C.48 -34.921234 -57.959473
# 580 C.15 C.49 -34.921823 -57.958647
# 581 C.15 C.50 -34.921823 -57.958647
# 582 C.15 Av.51 -34.922839 -57.957284
# 583 C.15 Av.53 -34.923749 -57.956061
# 584 C.15 C.54 -34.924268 -57.955353
# 585 C.15 C.55 -34.924778 -57.954672
# 586 C.15 C.56 -34.925306 -57.953835
# 587 C.15 C.57 -34.926041 -57.952977
# 588 C.15 C.58 -34.926765 -57.952017
# 589 C.15 C.59 -34.927565 -57.950971
# 590 C.15 Av.60 -34.928396 -57.949812
# 591 C.15 C.61 -34.929265 -57.948621
# 592 C.15 C.62 -34.930118 -57.947519
# 593 C.15 C.63 -34.930936 -57.946395
# 594 C.15 C.64 -34.931776 -57.945271
# 595 C.15 C.65 -34.932583 -57.944134
# 596 C.16 C.521 -34.899694 -57.990614
# 597 C.16 C.522 -34.900543 -57.989525
# 598 C.16 C.523 -34.901361 -57.988412
# 599 C.16 C.524 -34.902184 -57.987274
# 600 C.16 C.525 -34.903042 -57.986164
# 601 C.16 C.526 -34.903904 -57.984976
# 602 C.16 C.527 -34.904779 -57.983809
# 603 C.16 C.528 -34.905578 -57.982701
# 604 C.16 C.529 -34.906445 -57.981575
# 605 C.16 C.530 -34.907285 -57.980416
# 606 C.16 C.531 -34.907936 -57.979568
# 607 C.16 Av.32 -34.908785 -57.978380
# 608 C.16 C.33 -34.909872 -57.976991
# 609 C.16 C.34 -34.910672 -57.975864
# 610 C.16 C.35 -34.911536 -57.974764
# 611 C.16 C.36 -34.912366 -57.973629
# 612 C.16 C.37 -34.913212 -57.972508
# 613 C.16 Av.38 -34.914073 -57.971352
# 614 C.16 Calle_39 -34.914928 -57.970152
# 615 C.16 C.40 -34.915781 -57.969071
# 616 C.16 C.41 -34.916621 -57.967936
# 617 C.16 Calle_42 -34.917466 -57.966799
# 618 C.16 C.43 -34.918294 -57.965683
# 619 C.16 Av.44 -34.919127 -57.964522
# 620 C.16 C.45 -34.920005 -57.963336
# 621 C.16 C.46 -34.920764 -57.962317
# 622 C.16 C.47 -34.921481 -57.961346
# 623 C.16 C.48 -34.922158 -57.960445
# 624 C.16 C.49 -34.922778 -57.959688
# 625 C.16 C.50 -34.923269 -57.958975
# 626 C.16 Av.51 -34.923858 -57.958240
# 627 C.16 Av.53 -34.924661 -57.957065
# 628 C.16 C.54 -34.925173 -57.956384
# 629 C.16 C.55 -34.925705 -57.955548
# 630 C.16 C.56 -34.926233 -57.954893
# 631 C.16 C.57 -34.926946 -57.954014
# 632 C.16 C.58 -34.927717 -57.952990
# 633 C.16 C.59 -34.928465 -57.951978
# 634 C.16 Av.60 -34.929331 -57.950830
# 635 C.16 C.61 -34.930184 -57.949656
# 636 C.16 C.62 -34.931030 -57.948522
# 637 C.16 C.63 -34.931870 -57.947406
# 638 C.16 C.64 -34.932727 -57.946269
# 639 C.16 C.65 -34.933537 -57.945169
# 640 C.17 C.521 -34.900621 -57.991651
# 641 C.17 C.522 -34.901461 -57.990525
# 642 C.17 C.523 -34.902284 -57.989409
# 643 C.17 C.524 -34.903129 -57.988299
# 644 C.17 C.525 -34.903940 -57.987180
# 645 C.17 C.526 -34.904833 -57.986000
# 646 C.17 C.527 -34.905713 -57.984852
# 647 C.17 C.528 -34.906579 -57.983660
# 648 C.17 C.529 -34.907385 -57.982539
# 649 C.17 C.530 -34.908199 -57.981460
# 650 C.17 C.531 -34.908861 -57.980586
# 651 C.17 Av.32 -34.909701 -57.979341
# 652 C.17 C.33 -34.910794 -57.977992
# 653 C.17 C.34 -34.911624 -57.976890
# 654 C.17 C.35 -34.912440 -57.975788
# 655 C.17 C.36 -34.913330 -57.974583
# 656 C.17 C.37 -34.914120 -57.973543
# 657 C.17 Av.38 -34.914976 -57.972365
# 658 C.17 Calle_39 -34.915853 -57.971182
# 659 C.17 C.40 -34.916726 -57.970042
# 660 C.17 C.41 -34.917509 -57.968926
# 661 C.17 Calle_42 -34.918363 -57.967829
# 662 C.17 C.43 -34.919218 -57.966714
# 663 C.17 Av.44 -34.920054 -57.965574
# 664 C.17 C.45 -34.920923 -57.964364
# 665 C.17 C.46 -34.921710 -57.963302
# 666 C.17 C.47 -34.922458 -57.962347
# 667 C.17 C.48 -34.923142 -57.961435
# 668 C.17 C.49 -34.923698 -57.960673
# 669 C.17 C.50 -34.924199 -57.959954
# 670 C.17 Av.51 -34.924716 -57.959308
# 671 C.17 Av.53 -34.925603 -57.958088
# 672 C.17 C.54 -34.926159 -57.957323
# 673 C.17 C.55 -34.926610 -57.956669
# 674 C.17 C.56 -34.927250 -57.955864
# 675 C.17 C.57 -34.927914 -57.954987
# 676 C.17 C.58 -34.928582 -57.954054
# 677 C.17 C.59 -34.929394 -57.952986
# 678 C.17 Av.60 -34.930254 -57.951857
# 679 C.17 C.61 -34.931094 -57.950650
# 680 C.17 C.62 -34.931980 -57.949518
# 681 C.17 C.63 -34.932787 -57.948426
# 682 C.17 C.64 -34.933616 -57.947311
# 683 C.17 C.65 -34.934432 -57.946116
# 684 C.18 C.521 -34.901530 -57.992671
# 685 C.18 C.522 -34.902375 -57.991555
# 686 C.18 C.523 -34.903184 -57.990482
# 687 C.18 C.524 -34.903994 -57.989366
# 688 C.18 C.526 -34.905683 -57.987006
# 689 C.18 C.528 -34.907443 -57.984688
# 690 C.18 C.529 -34.908252 -57.983573
# 691 C.18 C.530 -34.909097 -57.982242
# 692 C.18 C.531 -34.909730 -57.981599
# 693 C.18 Av.32 -34.910434 -57.980440
# 694 C.18 C.33 -34.911736 -57.979024
# 695 C.18 C.34 -34.912475 -57.977908
# 696 C.18 C.35 -34.913285 -57.976835
# 697 C.18 C.36 -34.914165 -57.975676
# 698 C.18 C.37 -34.914974 -57.974560
# 699 C.18 Av.38 -34.915924 -57.973359
# 700 C.18 Calle_39 -34.916734 -57.972157
# 701 C.18 C.40 -34.917578 -57.971041
# 702 C.18 C.41 -34.918423 -57.969969
# 703 C.18 Calle_42 -34.919197 -57.968939
# 704 C.18 C.43 -34.920252 -57.967780
# 705 C.18 Av.44 -34.920956 -57.966492
# 706 C.18 C.45 -34.921801 -57.965419
# 707 C.18 C.46 -34.922575 -57.964390
# 708 C.18 C.47 -34.923349 -57.963402
# 709 C.18 C.48 -34.923982 -57.962544
# 710 C.18 C.49 -34.924563 -57.961729
# 711 C.18 C.50 -34.925267 -57.961042
# 712 C.18 Av.51 -34.925618 -57.960270
# 713 C.18 Av.53 -34.926516 -57.959047
# 714 C.18 C.54 -34.927026 -57.958403
# 715 C.18 C.55 -34.927659 -57.957652
# 716 C.18 C.56 -34.928152 -57.956901
# 717 C.18 C.57 -34.928820 -57.956021
# 718 C.18 C.58 -34.929524 -57.955034
# 719 C.18 C.59 -34.930509 -57.953918
# 720 C.18 Av.60 -34.931002 -57.952931
# 721 C.18 C.61 -34.931987 -57.951687
# 722 C.18 C.62 -34.932937 -57.950571
# 723 C.18 C.63 -34.933641 -57.949541
# 724 C.18 C.64 -34.934415 -57.948296
# 725 C.18 C.65 -34.935435 -57.947138
# 726 Av.19 C.521 -34.902463 -57.993744
# 727 Av.19 C.522 -34.903343 -57.992671
# 728 Av.19 C.523 -34.904082 -57.991469
# 729 Av.19 C.524 -34.904926 -57.990439
# 730 Av.19 C.525 -34.905841 -57.989195
# 731 Av.19 C.526 -34.906581 -57.988079
# 732 Av.19 C.527 -34.907496 -57.986963
# 733 Av.19 C.528 -34.908340 -57.985804
# 734 Av.19 C.529 -34.909115 -57.984688
# 735 Av.19 C.530 -34.910030 -57.983573
# 736 Av.19 C.531 -34.910733 -57.982800
# 737 Av.19 Av.32 -34.911669 -57.981521
# 738 Av.19 C.33 -34.912619 -57.980191
# 739 Av.19 C.34 -34.913605 -57.979032
# 740 Av.19 C.35 -34.914344 -57.977917
# 741 Av.19 C.36 -34.915083 -57.976758
# 742 Av.19 C.37 -34.916068 -57.975599
# 743 Av.19 Calle_39 -34.916877 -57.974398
# 744 Av.19 C.40 -34.918369 -57.971962
# 745 Av.19 C.41 -34.919389 -57.970975
# 746 Av.19 Calle_42 -34.920234 -57.969859
# 747 Av.19 C.43 -34.921043 -57.968743
# 748 Av.19 C.45 -34.922908 -57.966426
# 749 Av.19 C.46 -34.923506 -57.965396
# 750 Av.19 C.47 -34.924254 -57.964323
# 751 Av.19 C.48 -34.924966 -57.963572
# 752 Av.19 C.49 -34.925512 -57.962843
# 753 Av.19 C.50 -34.926040 -57.962070
# 754 Av.19 Av.51 -34.926585 -57.961362
# 755 Av.19 Av.53 -34.927429 -57.960096
# 756 Av.19 C.54 -34.928010 -57.959474
# 757 Av.19 C.55 -34.928502 -57.958658
# 758 Av.19 C.56 -34.929153 -57.957907
# 759 Av.19 C.57 -34.929769 -57.956963
# 760 Av.19 C.58 -34.930578 -57.956191
# 761 Av.19 C.59 -34.931264 -57.955075
# 762 Av.19 C.61 -34.932953 -57.952715
# 763 Av.19 C.62 -34.933798 -57.951534
# 764 Av.19 C.63 -34.934677 -57.950558
# 765 Av.19 C.64 -34.935469 -57.949324
# 766 Av.19 C.65 -34.936410 -57.948176
# 767 C.20 C.522 -34.904301 -57.993667
# 768 C.20 C.523 -34.905145 -57.992594
# 769 C.20 C.524 -34.905955 -57.991521
# 770 C.20 C.525 -34.906694 -57.990319
# 771 C.20 C.526 -34.907679 -57.989203
# 772 C.20 C.527 -34.908489 -57.988002
# 773 C.20 C.528 -34.909368 -57.986929
# 774 C.20 C.529 -34.910222 -57.985749
# 775 C.20 C.530 -34.911119 -57.984729
# 776 C.20 C.531 -34.911612 -57.983657
# 777 C.20 Av.32 -34.912633 -57.982584
# 778 C.20 C.33 -34.913618 -57.981082
# 779 C.20 C.34 -34.914392 -57.980095
# 780 C.20 C.35 -34.915272 -57.978936
# 781 C.20 C.36 -34.916116 -57.977777
# 782 C.20 C.37 -34.916961 -57.976704
# 783 C.20 Av.38 -34.917806 -57.975546
# 784 C.20 Calle_39 -34.918668 -57.974301
# 785 C.20 C.40 -34.919442 -57.973228
# 786 C.20 C.41 -34.920357 -57.972069
# 787 C.20 Calle_42 -34.921061 -57.971125
# 788 C.20 C.43 -34.922011 -57.969838
# 789 C.20 Av.44 -34.922925 -57.968636
# 790 C.20 C.45 -34.923700 -57.967520
# 791 C.20 C.46 -34.924403 -57.966533
# 792 C.20 C.47 -34.925177 -57.965503
# 793 C.20 C.48 -34.925635 -57.964688
# 794 C.20 C.49 -34.926479 -57.963830
# 795 C.20 C.50 -34.926479 -57.963830
# 796 C.20 Av.51 -34.927526 -57.962478
# 797 C.20 Av.53 -34.927526 -57.962478
# 798 C.20 C.54 -34.928916 -57.960525
# 799 C.20 C.55 -34.929444 -57.959924
# 800 C.20 C.56 -34.930077 -57.959066
# 801 C.20 C.57 -34.930745 -57.958165
# 802 C.20 C.58 -34.931484 -57.957307
# 803 C.20 C.59 -34.932153 -57.956148
# 804 C.20 Av.60 -34.932997 -57.955075
# 805 C.20 C.61 -34.933842 -57.953787
# 806 C.20 C.62 -34.934862 -57.952715
# 807 C.20 C.63 -34.935495 -57.951556
# 808 C.20 C.64 -34.936410 -57.950397
# 809 C.20 C.65 -34.937325 -57.949281
# 810 C.21 C.522 -34.905128 -57.994729
# 811 C.21 C.523 -34.906078 -57.993570
# 812 C.21 C.524 -34.906940 -57.992411
# 813 C.21 C.525 -34.907785 -57.991274
# 814 C.21 C.526 -34.908541 -57.990137
# 815 C.21 C.527 -34.908506 -57.988077
# 816 C.21 C.528 -34.909421 -57.986832
# 817 C.21 C.529 -34.910371 -57.985588
# 818 C.21 C.530 -34.911111 -57.984644
# 819 C.21 C.531 -34.911674 -57.983785
# 820 C.21 Av.32 -34.912518 -57.982584
# 821 C.21 C.33 -34.914524 -57.982197
# 822 C.21 C.34 -34.915404 -57.981082
# 823 C.21 C.35 -34.916213 -57.979966
# 824 C.21 C.36 -34.917058 -57.978893
# 825 C.21 C.37 -34.917762 -57.977605
# 826 C.21 Av.38 -34.918835 -57.976533
# 827 C.21 Calle_39 -34.919574 -57.975267
# 828 C.21 C.40 -34.920489 -57.974322
# 829 C.21 C.41 -34.921228 -57.973035
# 830 C.21 Calle_42 -34.922107 -57.972091
# 831 C.21 C.43 -34.922774 -57.970803
# 832 C.21 Av.44 -34.924005 -57.969602
# 833 C.21 C.45 -34.924674 -57.968615
# 834 C.21 C.46 -34.925483 -57.967585
# 835 C.21 C.47 -34.926187 -57.966726
# 836 C.21 C.48 -34.926891 -57.965611
# 837 C.21 C.49 -34.927454 -57.964924
# 838 C.21 C.50 -34.927911 -57.964152
# 839 C.21 Av.51 -34.928439 -57.963465
# 840 C.21 Av.53 -34.929389 -57.962306
# 841 C.21 C.54 -34.929916 -57.961534
# 842 C.21 C.55 -34.930339 -57.960890
# 843 C.21 C.56 -34.930972 -57.960032
# 844 C.21 C.57 -34.931676 -57.959173
# 845 C.21 C.58 -34.932344 -57.958143
# 846 C.21 C.59 -34.933153 -57.957199
# 847 C.21 Av.60 -34.933927 -57.956083
# 848 C.21 C.61 -34.934912 -57.954839
# 849 C.21 C.62 -34.935581 -57.953766
# 850 C.21 C.63 -34.936601 -57.952607
# 851 C.21 C.64 -34.937375 -57.951449
# 852 C.21 C.65 -34.938290 -57.950333
# 853 C.22 C.525 -34.908592 -57.992390
# 854 C.22 C.526 -34.909472 -57.991188
# 855 C.22 Av.32 -34.914469 -57.984622
# 856 C.22 C.33 -34.915560 -57.982991
# 857 C.22 C.34 -34.916299 -57.982090
# 858 C.22 C.35 -34.917073 -57.981017
# 859 C.22 C.36 -34.917883 -57.979816
# 860 C.22 C.37 -34.918727 -57.978829
# 861 C.22 Av.38 -34.919677 -57.977541
# 862 C.22 Calle_39 -34.920487 -57.976339
# 863 C.22 C.40 -34.921331 -57.975224
# 864 C.22 C.41 -34.922198 -57.973904
# 865 C.22 Calle_42 -34.922796 -57.973046
# 866 C.22 C.43 -34.924027 -57.971930
# 867 C.22 Av.44 -34.924625 -57.970642
# 868 C.22 C.45 -34.925611 -57.969612
# 869 C.22 C.46 -34.926350 -57.968540
# 870 C.22 C.47 -34.927124 -57.967467
# 871 C.22 C.48 -34.927687 -57.966694
# 872 C.22 C.49 -34.928320 -57.965836
# 873 C.22 C.50 -34.928848 -57.965149
# 874 C.22 Av.51 -34.929235 -57.964463
# 875 C.22 Av.53 -34.930202 -57.963240
# 876 C.22 C.54 -34.930748 -57.962489
# 877 C.22 C.55 -34.931240 -57.961802
# 878 C.22 C.56 -34.931979 -57.961072
# 879 C.22 C.57 -34.932507 -57.960128
# 880 C.22 C.58 -34.933281 -57.959184
# 881 C.22 C.59 -34.934090 -57.958154
# 882 C.22 Av.60 -34.934899 -57.956952
# 883 C.22 C.61 -34.935779 -57.955837
# 884 C.22 C.62 -34.936658 -57.954721
# 885 C.22 C.63 -34.937362 -57.953691
# 886 C.22 C.64 -34.938347 -57.952489
# 887 C.22 C.65 -34.939086 -57.951373
# 888 C.23 C.525 -34.909599 -57.993388
# 889 C.23 C.526 -34.910479 -57.992143
# 890 C.23 C.528 -34.912133 -57.989826
# 891 C.23 Av.32 -34.915441 -57.985620
# 892 C.23 C.33 -34.916427 -57.984247
# 893 C.23 C.34 -34.917201 -57.983131
# 894 C.23 C.35 -34.918045 -57.981972
# 895 C.23 C.36 -34.918819 -57.980813
# 896 C.23 C.37 -34.919699 -57.979698
# 897 C.23 Av.38 -34.920544 -57.978539
# 898 C.23 Calle_39 -34.921423 -57.977380
# 899 C.23 C.40 -34.922409 -57.976221
# 900 C.23 C.41 -34.923148 -57.975149
# 901 C.23 Calle_42 -34.924010 -57.974076
# 902 C.23 C.43 -34.924819 -57.972831
# 903 C.23 Av.44 -34.925593 -57.971672
# 904 C.23 C.45 -34.926508 -57.970557
# 905 C.23 C.46 -34.927247 -57.969570
# 906 C.23 C.47 -34.928056 -57.968540
# 907 C.23 C.48 -34.928689 -57.967638
# 908 C.23 C.49 -34.929252 -57.966866
# 909 C.23 C.50 -34.929692 -57.966093
# 910 C.23 Av.51 -34.930463 -57.965358
# 911 C.23 Av.53 -34.930463 -57.965358
# 912 C.23 C.54 -34.931694 -57.963535
# 913 C.23 C.55 -34.932222 -57.962934
# 914 C.23 C.56 -34.932855 -57.962033
# 915 C.23 C.57 -34.933524 -57.961217
# 916 C.23 C.58 -34.934228 -57.960273
# 917 C.23 C.59 -34.934931 -57.959243
# 918 C.23 Av.60 -34.935846 -57.958041
# 919 C.23 C.61 -34.936761 -57.956840
# 920 C.23 C.62 -34.937570 -57.955724
# 921 C.23 C.63 -34.938449 -57.954608
# 922 C.23 C.64 -34.939241 -57.953535
# 923 C.23 C.65 -34.940068 -57.952334
# 924 C.24 C.524 -34.909667 -57.995549
# 925 C.24 C.525 -34.910370 -57.994219
# 926 C.24 C.526 -34.911356 -57.993017
# 927 C.24 Av.32 -34.916353 -57.986666
# 928 C.24 C.33 -34.917338 -57.985293
# 929 C.24 C.34 -34.917338 -57.985293
# 930 C.24 C.35 -34.919133 -57.983040
# 931 C.24 C.36 -34.919766 -57.981924
# 932 C.24 C.37 -34.920681 -57.980722
# 933 C.24 Av.38 -34.921420 -57.979521
# 934 C.24 Calle_39 -34.922441 -57.978319
# 935 C.24 C.40 -34.923215 -57.977246
# 936 C.24 C.41 -34.923989 -57.976173
# 937 C.24 Calle_42 -34.924833 -57.975014
# 938 C.24 C.43 -34.925678 -57.973984
# 939 C.24 Av.44 -34.926663 -57.972783
# 940 C.24 C.45 -34.927402 -57.971581
# 941 C.24 C.46 -34.928246 -57.970551
# 942 C.24 C.47 -34.928915 -57.969693
# 943 C.24 C.48 -34.929583 -57.968663
# 944 C.24 C.49 -34.930181 -57.967805
# 945 C.24 C.50 -34.930780 -57.967204
# 946 C.24 C.54 -34.932715 -57.964586
# 947 C.24 C.55 -34.933242 -57.963856
# 948 C.24 C.56 -34.933841 -57.963127
# 949 C.24 C.57 -34.934403 -57.962226
# 950 C.24 C.58 -34.935142 -57.961110
# 951 C.24 C.59 -34.935811 -57.960123
# 952 C.24 Av.60 -34.935811 -57.960123
# 953 C.24 C.61 -34.937640 -57.957848
# 954 C.24 C.62 -34.938520 -57.956775
# 955 C.24 C.63 -34.939399 -57.955660
# 956 C.24 C.64 -34.940173 -57.954501
# 957 C.24 C.65 -34.940912 -57.953428
# 958 Av.25 C.522 -34.908927 -57.998961
# 959 Av.25 C.524 -34.910617 -57.996687
# 960 Av.25 C.525 -34.911461 -57.995528
# 961 Av.25 C.526 -34.912341 -57.994455
# 962 Av.25 C.527 -34.913397 -57.993168
# 963 Av.25 C.528 -34.914066 -57.992052
# 964 Av.25 C.529 -34.914910 -57.990936
# 965 Av.25 C.530 -34.915684 -57.989820
# 966 Av.25 C.531 -34.916423 -57.988876
# 967 Av.25 Av.32 -34.917197 -57.987760
# 968 Av.25 C.33 -34.918288 -57.986215
# 969 Av.25 C.34 -34.919063 -57.985357
# 970 Av.25 C.35 -34.919977 -57.984070
# 971 Av.25 C.36 -34.920857 -57.982846
# 972 Av.25 C.37 -34.921631 -57.981688
# 973 Av.25 Calle_39 -34.923355 -57.979456
# 974 Av.25 C.40 -34.924165 -57.978169
# 975 Av.25 C.41 -34.924939 -57.977139
# 976 Av.25 Calle_42 -34.925783 -57.976109
# 977 Av.25 Av.44 -34.927543 -57.973877
# 978 Av.25 C.45 -34.928422 -57.972504
# 979 Av.25 C.46 -34.929196 -57.971560
# 980 Av.25 C.47 -34.929900 -57.970616
# 981 Av.25 C.48 -34.930568 -57.969757
# 982 Av.25 C.49 -34.931131 -57.968985
# 983 Av.25 C.50 -34.931765 -57.968298
# 984 Av.25 Av.51 -34.932187 -57.967397
# 985 Av.25 C.54 -34.933559 -57.965509
# 986 Av.25 C.55 -34.934263 -57.964994
# 987 Av.25 C.56 -34.934790 -57.963964
# 988 Av.25 C.57 -34.935424 -57.963363
# 989 Av.25 C.58 -34.936127 -57.962247
# 990 Av.25 C.59 -34.937130 -57.961303
# 991 Av.25 C.61 -34.938643 -57.958900
# 992 Av.25 C.62 -34.939461 -57.957762
# 993 Av.25 C.63 -34.940314 -57.956625
# 994 Av.25 C.64 -34.941123 -57.955509
# 995 Av.25 C.65 -34.941932 -57.954522
# 996 C.26 C.522 -34.909878 -57.999927
# 997 C.26 C.523 -34.910582 -57.998682
# 998 C.26 C.524 -34.911497 -57.997609
# 999 C.26 C.525 -34.912447 -57.996536
# 1000 C.26 C.526 -34.913256 -57.995335
# 1001 C.26 C.527 -34.914206 -57.993962
# 1002 C.26 C.528 -34.914980 -57.992932
# 1003 C.26 C.529 -34.915790 -57.991730
# 1004 C.26 C.530 -34.916634 -57.990700
# 1005 C.26 C.531 -34.917268 -57.989842
# 1006 C.26 Av.32 -34.918148 -57.988769
# 1007 C.26 C.33 -34.919238 -57.987267
# 1008 C.26 C.34 -34.920083 -57.986151
# 1009 C.26 C.35 -34.920892 -57.985078
# 1010 C.26 C.36 -34.921684 -57.984005
# 1011 C.26 C.37 -34.922529 -57.982804
# 1012 C.26 Av.38 -34.923443 -57.981774
# 1013 C.26 Calle_39 -34.924288 -57.980400
# 1014 C.26 C.40 -34.925132 -57.979327
# 1015 C.26 C.41 -34.925977 -57.978297
# 1016 C.26 Calle_42 -34.926821 -57.977096
# 1017 C.26 C.43 -34.927595 -57.975937
# 1018 C.26 Av.44 -34.928510 -57.974864
# 1019 C.26 C.45 -34.929319 -57.973663
# 1020 C.26 C.46 -34.930093 -57.972590
# 1021 C.26 C.47 -34.930903 -57.971646
# 1022 C.26 C.48 -34.931501 -57.970744
# 1023 C.26 C.49 -34.932134 -57.970015
# 1024 C.26 C.50 -34.932592 -57.969199
# 1025 C.26 C.54 -34.934597 -57.966624
# 1026 C.26 C.55 -34.935054 -57.965938
# 1027 C.26 C.56 -34.935652 -57.965165
# 1028 C.26 C.57 -34.936497 -57.964264
# 1029 C.26 C.58 -34.937095 -57.963320
# 1030 C.26 C.59 -34.937798 -57.962333
# 1031 C.26 Av.60 -34.938748 -57.961131
# 1032 C.26 C.61 -34.939769 -57.959715
# 1033 C.26 C.62 -34.940472 -57.958814
# 1034 C.26 C.63 -34.941316 -57.957827
# 1035 C.26 C.64 -34.942020 -57.956582
# 1036 C.26 C.65 -34.943040 -57.955467
# 1037 C.27 C.522 -34.911725 -57.999798
# 1038 C.27 C.523 -34.910881 -58.000656
# 1039 C.27 C.524 -34.912500 -57.998682
# 1040 C.27 C.525 -34.912957 -57.997137
# 1041 C.27 C.526 -34.914365 -57.996150
# 1042 C.27 C.527 -34.915033 -57.995249
# 1043 C.27 C.528 -34.915948 -57.994047
# 1044 C.27 C.529 -34.916652 -57.992846
# 1045 C.27 C.530 -34.917567 -57.991773
# 1046 C.27 C.531 -34.918271 -57.990893
# 1047 C.27 Av.32 -34.919080 -57.989649
# 1048 C.27 C.33 -34.920065 -57.988275
# 1049 C.27 C.34 -34.921543 -57.987031
# 1050 C.27 C.35 -34.921684 -57.986258
# 1051 C.27 C.36 -34.922740 -57.985142
# 1052 C.27 C.37 -34.923197 -57.983512
# 1053 C.27 Av.38 -34.924429 -57.982653
# 1054 C.27 Calle_39 -34.925273 -57.981538
# 1055 C.27 C.40 -34.926012 -57.980336
# 1056 C.27 C.41 -34.926892 -57.979306
# 1057 C.27 Calle_42 -34.927771 -57.978104
# 1058 C.27 C.43 -34.928651 -57.976946
# 1059 C.27 Av.44 -34.929425 -57.975787
# 1060 C.27 C.45 -34.930305 -57.974671
# 1061 C.27 C.46 -34.931043 -57.973641
# 1062 C.27 C.47 -34.931853 -57.972783
# 1063 C.27 C.48 -34.932662 -57.971839
# 1064 C.27 C.49 -34.932838 -57.971152
# 1065 C.27 C.50 -34.933718 -57.969996
# 1066 C.27 Av.51 -34.934176 -57.969524
# 1067 C.27 Av.53 -34.934985 -57.968365
# 1068 C.27 C.54 -34.935583 -57.967764
# 1069 C.27 C.55 -34.936076 -57.966992
# 1070 C.27 C.56 -34.936821 -57.966295
# 1071 C.27 C.57 -34.937278 -57.965522
# 1072 C.27 C.58 -34.937947 -57.964492
# 1073 C.27 C.59 -34.938791 -57.963419
# 1074 C.27 Av.60 -34.939460 -57.962175
# 1075 C.27 C.61 -34.940603 -57.960973
# 1076 C.27 C.62 -34.941377 -57.959879
# 1077 C.27 C.63 -34.942151 -57.958763
# 1078 C.27 C.64 -34.943066 -57.957561
# 1079 C.27 C.65 -34.943839 -57.956488
# 1080 Calle_28 C.522 -34.911768 -58.001893
# 1081 Calle_28 C.523 -34.912683 -58.000734
# 1082 Calle_28 C.524 -34.913317 -57.999618
# 1083 Calle_28 C.525 -34.914267 -57.998417
# 1084 Calle_28 C.526 -34.915147 -57.997215
# 1085 Calle_28 C.527 -34.915991 -57.996185
# 1086 Calle_28 C.528 -34.916800 -57.995155
# 1087 Calle_28 C.529 -34.917680 -57.993954
# 1088 Calle_28 C.530 -34.918525 -57.992838
# 1089 Calle_28 C.531 -34.919193 -57.991894
# 1090 Calle_28 Av.32 -34.920038 -57.990778
# 1091 Calle_28 C.33 -34.921094 -57.989490
# 1092 Calle_28 C.34 -34.921727 -57.988289
# 1093 Calle_28 C.35 -34.922712 -57.987173
# 1094 Calle_28 C.36 -34.923873 -57.986100
# 1095 Calle_28 C.37 -34.924401 -57.984855
# 1096 Calle_28 Av.38 -34.925246 -57.983783
# 1097 Calle_28 Calle_39 -34.926196 -57.982495
# 1098 Calle_28 C.40 -34.926970 -57.981465
# 1099 Calle_28 C.41 -34.927779 -57.980349
# 1100 Calle_28 Calle_42 -34.928694 -57.979191
# 1101 Calle_28 C.43 -34.929503 -57.978032
# 1102 Calle_28 Av.44 -34.930418 -57.976830
# 1103 Calle_28 C.45 -34.931368 -57.975629
# 1104 Calle_28 C.46 -34.931966 -57.974685
# 1105 Calle_28 C.47 -34.932740 -57.973697
# 1106 Calle_28 C.48 -34.933648 -57.972914
# 1107 Calle_28 C.49 -34.934035 -57.972056
# 1108 Calle_28 C.50 -34.934598 -57.971455
# 1109 Calle_28 Av.51 -34.934985 -57.970683
# 1110 Calle_28 Av.53 -34.935865 -57.969395
# 1111 Calle_28 C.54 -34.936463 -57.968666
# 1112 Calle_28 C.55 -34.936955 -57.967936
# 1113 Calle_28 C.56 -34.937553 -57.967207
# 1114 Calle_28 C.57 -34.938257 -57.966305
# 1115 Calle_28 C.58 -34.938890 -57.965275
# 1116 Calle_28 C.59 -34.939699 -57.964331
# 1117 Calle_28 Av.60 -34.940614 -57.963130
# 1118 Calle_28 C.61 -34.941071 -57.961585
# 1119 Calle_28 C.62 -34.942338 -57.960898
# 1120 Calle_28 C.63 -34.943182 -57.959696
# 1121 Calle_28 C.64 -34.944026 -57.958666
# 1122 Calle_28 C.65 -34.944730 -57.957465
# 1123 C.29 C.522 -34.912571 -58.002869
# 1124 C.29 C.523 -34.913521 -58.001839
# 1125 C.29 C.524 -34.914401 -58.000723
# 1126 C.29 C.525 -34.915140 -57.999608
# 1127 C.29 C.526 -34.916020 -57.998320
# 1128 C.29 C.527 -34.916935 -57.997204
# 1129 C.29 C.528 -34.917779 -57.996003
# 1130 C.29 C.529 -34.918624 -57.994973
# 1131 C.29 C.530 -34.919468 -57.993771
# 1132 C.29 C.531 -34.920031 -57.992827
# 1133 C.29 Av.32 -34.920981 -57.991711
# 1134 C.29 C.33 -34.921791 -57.990381
# 1135 C.29 C.34 -34.922811 -57.989265
# 1136 C.29 C.35 -34.923656 -57.988063
# 1137 C.29 C.36 -34.924641 -57.987033
# 1138 C.29 C.37 -34.925380 -57.985875
# 1139 C.29 Av.38 -34.926224 -57.984673
# 1140 C.29 Calle_39 -34.926787 -57.983557
# 1141 C.29 C.40 -34.927878 -57.982399
# 1142 C.29 C.41 -34.928722 -57.981326
# 1143 C.29 Calle_42 -34.929532 -57.980124
# 1144 C.29 C.43 -34.930482 -57.979180
# 1145 C.29 Av.44 -34.931256 -57.977892
# 1146 C.29 C.45 -34.932135 -57.976605
# 1147 C.29 C.46 -34.932944 -57.975704
# 1148 C.29 C.47 -34.933648 -57.974845
# 1149 C.29 C.48 -34.934281 -57.973858
# 1150 C.29 C.49 -34.934880 -57.973000
# 1151 C.29 C.50 -34.935161 -57.971970
# 1152 C.29 Av.51 -34.935970 -57.971756
# 1153 C.29 Av.53 -34.885116 -57.976523
# 1154 C.29 C.54 -34.937373 -57.969712
# 1155 C.29 C.55 -34.937901 -57.968993
# 1156 C.29 C.56 -34.938489 -57.968194
# 1157 C.29 C.57 -34.939153 -57.967329
# 1158 C.29 C.58 -34.939859 -57.966366
# 1159 C.29 C.59 -34.940637 -57.965312
# 1160 C.29 Av.60 -34.941492 -57.964161
# 1161 C.29 C.61 -34.942380 -57.962967
# 1162 C.29 C.62 -34.943191 -57.961840
# 1163 C.29 C.63 -34.944024 -57.960751
# 1164 C.29 C.64 -34.944873 -57.959614
# 1165 C.29 C.65 -34.945693 -57.958493
# 1166 C.30 C.522 -34.913602 -58.003864
# 1167 C.30 C.523 -34.914442 -58.002741
# 1168 C.30 C.524 -34.915260 -58.001641
# 1169 C.30 C.525 -34.915893 -58.000257
# 1170 C.30 C.526 -34.916931 -57.999404
# 1171 C.30 C.527 -34.917877 -57.998165
# 1172 C.30 C.528 -34.918690 -57.997047
# 1173 C.30 C.529 -34.919515 -57.995939
# 1174 C.30 C.530 -34.920360 -57.994786
# 1175 C.30 C.531 -34.921015 -57.993917
# 1176 C.30 Av.32 -34.921895 -57.992769
# 1177 C.30 C.33 -34.922944 -57.991345
# 1178 C.30 C.34 -34.923982 -57.990326
# 1179 C.30 C.35 -34.924620 -57.989098
# 1180 C.30 C.36 -34.925434 -57.987990
# 1181 C.30 C.37 -34.926285 -57.986855
# 1182 C.30 Av.38 -34.927162 -57.985699
# 1183 C.30 Calle_39 -34.928037 -57.984522
# 1184 C.30 C.40 -34.928854 -57.983400
# 1185 C.30 C.41 -34.929694 -57.982282
# 1186 C.30 Calle_42 -34.930512 -57.981172
# 1187 C.30 C.43 -34.931340 -57.980041
# 1188 C.30 Av.44 -34.932224 -57.978864
# 1189 C.30 C.45 -34.933080 -57.977697
# 1190 C.30 C.46 -34.933889 -57.976672
# 1191 C.30 C.47 -34.934581 -57.975690
# 1192 C.30 C.48 -34.935221 -57.974831
# 1193 C.30 C.49 -34.935848 -57.974032
# 1194 C.30 C.50 -34.936360 -57.973313
# 1195 C.30 Av.51 -34.936875 -57.972626
# 1196 C.30 Av.53 -34.937737 -57.971446
# 1197 C.30 C.54 -34.938271 -57.970727
# 1198 C.30 C.55 -34.938810 -57.970016
# 1199 C.30 C.56 -34.939393 -57.969222
# 1200 C.30 C.57 -34.940042 -57.968350
# 1201 C.30 C.58 -34.940770 -57.967387
# 1202 C.30 C.59 -34.941568 -57.966349
# 1203 C.30 Av.60 -34.942410 -57.965182
# 1204 C.30 C.61 -34.943296 -57.963994
# 1205 C.30 C.62 -34.944125 -57.962881
# 1206 C.30 C.63 -34.944947 -57.961744
# 1207 C.30 C.64 -34.945785 -57.960617
# 1208 C.30 C.65 -34.946614 -57.959509
# 1209 Av.31 C.522 -34.914572 -58.004940
# 1210 Av.31 C.523 -34.915408 -58.003814
# 1211 Av.31 C.524 -34.916253 -58.002685
# 1212 Av.31 C.526 -34.917938 -58.000410
# 1213 Av.31 C.527 -34.918827 -57.999246
# 1214 Av.31 C.528 -34.919654 -57.998103
# 1215 Av.31 C.529 -34.920468 -57.996987
# 1216 Av.31 C.530 -34.921307 -57.995870
# 1217 Av.31 C.531 -34.922165 -57.994763
# 1218 Av.31 Av.32 -34.922699 -57.993996
# 1219 Av.31 C.33 -34.923876 -57.992354
# 1220 Av.31 C.34 -34.924699 -57.991252
# 1221 Av.31 C.35 -34.925541 -57.990107
# 1222 Av.31 C.36 -34.926853 -57.989463
# 1223 Av.31 C.37 -34.927653 -57.988390
# 1224 Av.31 Av.38 -34.928058 -57.986805
# 1225 Av.31 Calle_39 -34.928968 -57.985571
# 1226 Av.31 C.40 -34.929804 -57.984461
# 1227 Av.31 C.41 -34.930629 -57.983332
# 1228 Av.31 Calle_42 -34.931478 -57.982197
# 1229 Av.31 C.43 -34.932300 -57.981085
# 1230 Av.31 Av.44 -34.933153 -57.979908
# 1231 Av.31 C.45 -34.934033 -57.978757
# 1232 Av.31 C.46 -34.934807 -57.977735
# 1233 Av.31 C.47 -34.935517 -57.976740
# 1234 Av.31 C.48 -34.936168 -57.975872
# 1235 Av.31 C.49 -34.936771 -57.975079
# 1236 Av.31 C.50 -34.937307 -57.974351
# 1237 Av.31 Av.51 -34.937834 -57.973675
# 1238 Av.31 Av.53 -34.938760 -57.972388
# 1239 Av.31 C.54 -34.939222 -57.971771
# 1240 Av.31 C.55 -34.939741 -57.971039
# 1241 Av.31 C.56 -34.940337 -57.970218
# 1242 Av.31 C.57 -34.940960 -57.969395
# 1243 Av.31 C.58 -34.941703 -57.968408
# 1244 Av.31 C.59 -34.942484 -57.967370
# 1245 Av.31 Av.60 -34.943350 -57.966206
# 1246 Av.31 C.61 -34.944229 -57.965058
# 1247 Av.31 C.62 -34.945042 -57.963934
# 1248 Av.31 C.63 -34.945906 -57.962797
# 1249 Av.31 C.64 -34.946719 -57.961668
# 1250 Av.31 C.65 -34.947568 -57.960555
# 1251 C.132 C.522 -34.915538 -58.005969
# 1252 C.132 C.523 -34.916372 -58.004850
# 1253 C.132 C.524 -34.919731 -58.002265
# 1254 C.132 C.526 -34.919731 -58.002265
# 1255 C.132 C.527 -34.920554 -58.001106
# 1256 C.132 C.528 -34.921012 -57.999569
# 1257 C.132 C.529 -34.921866 -57.998500
# 1258 C.132 C.530 -34.922690 -57.997363
# 1259 C.132 C.531 -34.923536 -57.996243
# 1260 C.132 Av.32 -34.924385 -57.995076
# 1261 C.132 C.33 -34.925265 -57.993901
# 1262 C.132 C.34 -34.926101 -57.992780
# 1263 C.132 C.35 -34.926927 -57.991651
# 1264 C.132 C.36 -34.927785 -57.990522
# 1265 C.132 C.37 -34.928604 -57.989422
# 1266 C.132 Av.38 -34.929440 -57.988257
# 1267 C.132 Calle_39 -34.930347 -57.987090
# 1268 C.132 C.40 -34.931184 -57.985961
# 1269 C.132 C.41 -34.932013 -57.984840
# 1270 C.132 Calle_42 -34.932844 -57.983724
# 1271 C.132 C.43 -34.933695 -57.982595
# 1272 C.132 Av.44 -34.934544 -57.981436
# 1273 C.132 C.45 -34.935420 -57.980269
# 1274 C.132 C.46 -34.936267 -57.979126
# 1275 C.132 C.47 -34.937098 -57.978009
# 1276 C.132 C.48 -34.937588 -57.977363
# 1277 C.132 C.49 -34.937928 -57.976893
# 1278 C.132 C.50 -34.938757 -57.975772
# 1279 C.132 C.56 -34.941362 -57.972269
# 1280 C.132 C.57 -34.942204 -57.971148
# 1281 C.132 C.58 -34.943038 -57.970027
# 1282 C.132 C.59 -34.943873 -57.968909
# 1283 C.132 Av.60 -34.944739 -57.967737
# 1284 C.132 C.61 -34.945623 -57.966573
# 1285 C.132 C.62 -34.946439 -57.965428
# 1286 C.132 C.63 -34.947274 -57.964301
# 1287 C.132 C.64 -34.948112 -57.963191
# 1288 C.132 C.65 -34.948936 -57.962078
# 1289 C.133 C.521 -34.916405 -58.008919
# 1290 C.133 C.522 -34.916995 -58.007596
# 1291 C.133 C.523 -34.917703 -58.006357
# 1292 C.133 C.524 -34.918532 -58.005206
# 1293 C.133 C.525 -34.919320 -58.004063
# 1294 C.133 C.526 -34.920235 -58.002903
# 1295 C.133 C.527 -34.921103 -58.001745
# 1296 C.133 C.528 -34.921945 -58.000613
# 1297 C.133 C.529 -34.922779 -57.999486
# 1298 C.133 C.530 -34.923598 -57.998388
# 1299 C.133 C.531 -34.924447 -57.997270
# 1300 C.133 Av.32 -34.925335 -57.996084
# 1301 C.133 C.33 -34.926175 -57.994947
# 1302 C.133 C.34 -34.927024 -57.993802
# 1303 C.133 C.35 -34.927879 -57.992663
# 1304 C.133 C.36 -34.928711 -57.991529
# 1305 C.133 C.37 -34.929519 -57.990436
# 1306 C.133 Av.38 -34.930402 -57.989270
# 1307 C.133 Calle_39 -34.931266 -57.988093
# 1308 C.133 C.40 -34.932099 -57.986985
# 1309 C.133 C.41 -34.932948 -57.985852
# 1310 C.133 Calle_42 -34.933766 -57.984728
# 1311 C.133 C.43 -34.934602 -57.983601
# 1312 C.133 Av.44 -34.935470 -57.982445
# 1313 C.133 C.45 -34.936342 -57.981268
# 1314 C.133 C.46 -34.937170 -57.980146
# 1315 C.133 C.47 -34.938019 -57.979022
# 1316 C.133 C.48 -34.938440 -57.978464
# 1317 C.133 C.49 -34.938853 -57.977918
# 1318 C.133 C.50 -34.939685 -57.976778
# 1319 C.133 C.56 -34.942293 -57.973272
# 1320 C.133 C.57 -34.943133 -57.972145
# 1321 C.133 C.58 -34.943962 -57.971037
# 1322 C.133 C.59 -34.944786 -57.969897
# 1323 C.133 Av.60 -34.945660 -57.968745
# 1324 C.133 C.61 -34.946535 -57.967573
# 1325 C.133 C.62 -34.947367 -57.966458
# 1326 C.133 C.63 -34.948196 -57.965313
# 1327 C.133 C.64 -34.949029 -57.964192
# 1328 C.133 C.65 -34.949890 -57.963100
# 1329 C.134 C.521 -34.917703 -58.006357
# 1330 C.134 C.522 -34.917813 -58.008481
# 1331 C.134 C.523 -34.918642 -58.007363
# 1332 C.134 C.524 -34.919462 -58.006218
# 1333 C.134 C.525 -34.920293 -58.005113
# 1334 C.134 C.526 -34.921171 -58.003946
# 1335 C.134 C.527 -34.922024 -58.002779
# 1336 C.134 C.528 -34.922860 -58.001626
# 1337 C.134 C.529 -34.923689 -58.000518
# 1338 C.134 C.530 -34.924533 -57.999402
# 1339 C.134 C.531 -34.925366 -57.998273
# 1340 C.134 Av.32 -34.926259 -57.997106
# 1341 C.134 C.33 -34.927117 -57.995934
# 1342 C.134 C.34 -34.927946 -57.994799
# 1343 C.134 C.35 -34.928777 -57.993672
# 1344 C.134 C.36 -34.929610 -57.992559
# 1345 C.134 C.37 -34.930452 -57.991430
# 1346 C.134 Av.38 -34.931323 -57.990269
# 1347 C.134 Calle_39 -34.932193 -57.989095
# 1348 C.134 C.40 -34.933009 -57.988001
# 1349 C.134 C.41 -34.933856 -57.986864
# 1350 C.134 Calle_42 -34.934687 -57.985751
# 1351 C.134 Av.44 -34.936412 -57.983459
# 1352 C.134 C.46 -34.938096 -57.981154
# 1353 C.134 C.47 -34.938940 -57.980034
# 1354 C.134 C.48 -34.939364 -57.979481
# 1355 C.134 C.49 -34.939777 -57.978912
# 1356 C.134 C.50 -34.940613 -57.977804
# 1357 C.134 C.56 -34.943223 -57.974307
# 1358 C.134 C.57 -34.944055 -57.973168
# 1359 C.134 C.58 -34.944893 -57.972052
# 1360 C.134 C.59 -34.945720 -57.970923
# 1361 C.134 Av.60 -34.946597 -57.969743
# 1362 C.134 C.61 -34.947454 -57.968571
# 1363 C.134 C.62 -34.948289 -57.967458
# 1364 C.134 C.63 -34.949131 -57.966350
# 1365 C.134 C.64 -34.949975 -57.965232
# 1366 C.134 C.65 -34.950829 -57.964124
# 1367 C.135 C.521 -34.917897 -58.010611
# 1368 C.135 C.522 -34.918709 -58.009490
# 1369 C.135 C.523 -34.919545 -58.008374
# 1370 C.135 C.524 -34.920394 -58.007264
# 1371 C.135 C.525 -34.921214 -58.006108
# 1372 C.135 C.526 -34.922102 -58.004928
# 1373 C.135 C.527 -34.922944 -58.003775
# 1374 C.135 C.528 -34.923775 -58.002630
# 1375 C.135 C.529 -34.924619 -58.001536
# 1376 C.135 C.530 -34.925459 -58.000407
# 1377 C.135 C.531 -34.926277 -57.999283
# 1378 C.135 Av.32 -34.927168 -57.998124
# 1379 C.135 C.33 -34.928043 -57.996936
# 1380 C.135 C.34 -34.928870 -57.995825
# 1381 C.135 C.35 -34.929697 -57.994693
# 1382 C.135 C.36 -34.930535 -57.993583
# 1383 C.135 C.37 -34.931397 -57.992446
# 1384 C.135 Av.38 -34.932239 -57.991303
# 1385 C.135 Calle_39 -34.933134 -57.990123
# 1386 C.135 C.40 -34.933967 -57.989002
# 1387 C.135 C.41 -34.934763 -57.987881
# 1388 C.135 Calle_42 -34.935605 -57.986763
# 1389 C.135 C.43 -34.936150 -57.986041
# 1390 C.135 Av.44 -34.937329 -57.984456
# 1391 C.135 C.45 -34.938182 -57.983308
# 1392 C.135 C.46 -34.939019 -57.982174
# 1393 C.135 C.47 -34.939861 -57.981056
# 1394 C.135 C.48 -34.940272 -57.980501
# 1395 C.135 C.49 -34.940701 -57.979923
# 1396 C.135 C.50 -34.941543 -57.978822
# 1397 C.135 C.56 -34.944148 -57.975311
# 1398 C.135 C.57 -34.944988 -57.974176
# 1399 C.135 C.58 -34.945810 -57.973063
# 1400 C.135 C.59 -34.946656 -57.971939
# 1401 C.135 Av.60 -34.947509 -57.970767
# 1402 C.135 C.61 -34.948369 -57.969595
# 1403 C.135 C.62 -34.949215 -57.968477
# 1404 C.135 C.63 -34.950036 -57.967353
# 1405 C.135 C.64 -34.950884 -57.966228
# 1406 C.135 C.65 -34.950829 -57.964124
# 1407 C.136 C.521 -34.918817 -58.011612
# 1408 C.136 C.522 -34.919609 -58.010483
# 1409 C.136 C.523 -34.920471 -58.009373
# 1410 C.136 C.524 -34.921313 -58.008246
# 1411 C.136 C.525 -34.922138 -58.007117
# 1412 C.136 C.526 -34.923048 -58.005915
# 1413 C.136 C.527 -34.923879 -58.004788
# 1414 C.136 C.528 -34.924688 -58.003683
# 1415 C.136 C.529 -34.925548 -58.002555
# 1416 C.136 C.530 -34.926392 -58.001418
# 1417 C.136 C.531 -34.927211 -58.000303
# 1418 C.136 Av.32 -34.928086 -57.999123
# 1419 C.136 C.33 -34.928974 -57.997967
# 1420 C.136 C.34 -34.929805 -57.996848
# 1421 C.136 C.35 -34.930647 -57.995711
# 1422 C.136 C.36 -34.931456 -57.994584
# 1423 C.136 C.37 -34.932270 -57.993404
# 1424 C.136 Av.38 -34.933152 -57.992283
# 1425 C.136 Calle_39 -34.934040 -57.991132
# 1426 C.136 C.40 -34.934876 -57.990016
# 1427 C.136 Calle_42 -34.936552 -57.987768
# 1428 C.136 C.43 -34.937095 -57.987028
# 1429 C.136 Av.44 -34.938212 -57.985523
# 1430 C.136 C.45 -34.939122 -57.984297
# 1431 C.136 C.46 -34.939916 -57.983189
# 1432 C.136 C.47 -34.940785 -57.982084
# 1433 C.136 C.48 -34.941205 -57.981523
# 1434 C.136 C.49 -34.941625 -57.980944
# 1435 C.136 C.50 -34.942474 -57.979828
# 1436 C.136 C.56 -34.945083 -57.976321
# 1437 C.136 C.57 -34.945896 -57.975176
# 1438 C.136 C.58 -34.946747 -57.974044
# 1439 C.136 C.59 -34.947569 -57.972960
# 1440 C.136 Av.60 -34.948437 -57.971777
# 1441 C.136 C.61 -34.949303 -57.970618
# 1442 C.136 C.62 -34.950143 -57.969486
# 1443 C.136 C.63 -34.950989 -57.968359
# 1444 C.136 C.64 -34.951816 -57.967254
# 1445 C.136 C.65 -34.952647 -57.966127
# 1446 Av.137 C.521 -34.919832 -58.012676
# 1447 Av.137 C.522 -34.920636 -58.011566
# 1448 Av.137 C.523 -34.921419 -58.010490
# 1449 Av.137 C.524 -34.922243 -58.009283
# 1450 Av.137 C.525 -34.923092 -58.008154
# 1451 Av.137 C.526 -34.923897 -58.007162
# 1452 Av.137 C.527 -34.924840 -58.005832
# 1453 Av.137 C.528 -34.925679 -58.004712
# 1454 Av.137 C.529 -34.926517 -58.003604
# 1455 Av.137 C.530 -34.927350 -58.002469
# 1456 Av.137 C.531 -34.928181 -58.001359
# 1457 Av.137 Av.32 -34.929052 -58.000209
# 1458 Av.137 C.33 -34.929925 -57.999026
# 1459 Av.137 C.34 -34.930754 -57.997902
# 1460 Av.137 C.35 -34.931598 -57.996765
# 1461 Av.137 C.36 -34.932436 -57.995644
# 1462 Av.137 C.37 -34.933274 -57.994509
# 1463 Av.137 Av.38 -34.934121 -57.993380
# 1464 Av.137 Calle_39 -34.935007 -57.992181
# 1465 Av.137 C.40 -34.935841 -57.991037
# 1466 Av.137 C.41 -34.936672 -57.989936
# 1467 Av.137 Calle_42 -34.937519 -57.988826
# 1468 Av.137 C.43 -34.938328 -57.987713
# 1469 Av.137 Av.44 -34.939216 -57.986538
# 1470 Av.137 C.45 -34.940082 -57.985365
# 1471 Av.137 C.46 -34.940913 -57.984235
# 1472 Av.137 C.47 -34.941746 -57.983106
# 1473 Av.137 C.48 -34.942122 -57.982621
# 1474 Av.137 C.49 -34.942582 -57.982000
# 1475 Av.137 C.50 -34.943412 -57.980877
# 1476 Av.137 C.56 -34.946001 -57.977318
# 1477 Av.137 C.57 -34.946808 -57.976216
# 1478 Av.137 C.58 -34.947659 -57.975063
# 1479 Av.137 C.59 -34.948501 -57.973958
# 1480 Av.137 Av.60 -34.949350 -57.972805
# 1481 Av.137 C.61 -34.950234 -57.971625
# 1482 Av.137 C.62 -34.951074 -57.970472
# 1483 Av.137 C.63 -34.951907 -57.969380
# 1484 Av.137 C.64 -34.952745 -57.968251
# 1485 Av.137 C.65 -34.953572 -57.967141
# 1486 C.138 C.521 -34.920730 -58.013744
# 1487 C.138 C.522 -34.921568 -58.012599
# 1488 C.138 C.523 -34.922405 -58.011496
# 1489 C.138 C.524 -34.923232 -58.010359
# 1490 C.138 C.525 -34.924065 -58.009243
# 1491 C.138 C.526 -34.924828 -58.008154
# 1492 C.138 C.527 -34.925788 -58.006896
# 1493 C.138 C.528 -34.926628 -58.005778
# 1494 C.138 C.529 -34.927477 -58.004673
# 1495 C.138 C.530 -34.928314 -58.003532
# 1496 C.138 C.531 -34.929147 -58.002400
# 1497 C.138 Av.32 -34.930025 -58.001245
# 1498 C.138 C.33 -34.930889 -58.000078
# 1499 C.138 C.34 -34.931714 -57.998966
# 1500 C.138 C.35 -34.932561 -57.997829
# 1501 C.138 C.36 -34.933390 -57.996686
# 1502 C.138 Av.38 -34.935070 -57.994422
# 1503 C.138 Calle_39 -34.935956 -57.993252
# 1504 C.138 C.40 -34.936801 -57.992140
# 1505 C.138 C.41 -34.937637 -57.991004
# 1506 C.138 Calle_42 -34.938466 -57.989880
# 1507 C.138 C.43 -34.939299 -57.988767
# 1508 C.138 Av.44 -34.940126 -57.987643
# 1509 C.138 C.45 -34.941041 -57.986423
# 1510 C.138 C.46 -34.941874 -57.985307
# 1511 C.138 C.47 -34.942712 -57.984189
# 1512 C.138 C.48 -34.943116 -57.983624
# 1513 C.138 C.49 -34.943536 -57.983053
# 1514 C.138 C.50 -34.944395 -57.981921
# 1515 C.138 C.56 -34.947409 -57.977874
# 1516 C.138 C.57 -34.947838 -57.977305
# 1517 C.138 C.58 -34.948662 -57.976178
# 1518 C.138 C.59 -34.949471 -57.975081
# 1519 C.138 Av.60 -34.950346 -57.973917
# 1520 C.138 C.61 -34.951243 -57.972723
# 1521 C.138 C.62 -34.952072 -57.971613
# 1522 C.138 C.63 -34.952896 -57.970482
# 1523 C.138 C.64 -34.953728 -57.969348
# 1524 C.138 C.65 -34.954577 -57.968243
# 1525 C.139 C.521 -34.921667 -58.014738
# 1526 C.139 C.522 -34.922505 -58.013620
# 1527 C.139 C.523 -34.923336 -58.012502
# 1528 C.139 C.524 -34.924178 -58.011378
# 1529 C.139 C.525 -34.924996 -58.010292
# 1530 C.139 C.526 -34.925871 -58.009112
# 1531 C.139 C.527 -34.926722 -58.007913
# 1532 C.139 C.528 -34.927562 -58.006789
# 1533 C.139 C.529 -34.928403 -58.005654
# 1534 C.139 C.530 -34.929221 -58.004541
# 1535 C.139 C.531 -34.930074 -58.003431
# 1536 C.139 Av.32 -34.930938 -58.002254
# 1537 C.139 C.33 -34.931812 -58.001092
# 1538 C.139 C.34 -34.932633 -57.999975
# 1539 C.139 C.35 -34.933477 -57.998842
# 1540 C.139 C.36 -34.934319 -57.997707
# 1541 C.139 Av.38 -34.936012 -57.995424
# 1542 C.139 Calle_39 -34.936896 -57.994247
# 1543 C.139 C.40 -34.937729 -57.993150
# 1544 C.139 C.41 -34.938578 -57.992032
# 1545 C.139 Calle_42 -34.939392 -57.990892
# 1546 C.139 C.43 -34.940241 -57.989757
# 1547 C.139 Av.44 -34.941088 -57.988612
# 1548 C.139 C.45 -34.941967 -57.987418
# 1549 C.139 C.46 -34.942805 -57.986321
# 1550 C.139 C.47 -34.943651 -57.985192
# 1551 C.139 C.48 -34.944065 -57.984634
# 1552 C.139 C.49 -34.944487 -57.984076
# 1553 C.139 C.50 -34.945300 -57.982960
# 1554 C.139 C.56 -34.948370 -57.978840
# 1555 C.139 C.57 -34.948743 -57.978323
# 1556 C.139 C.58 -34.949584 -57.977191
# 1557 C.139 C.59 -34.950419 -57.976070
# 1558 C.139 Av.60 -34.951278 -57.974902
# 1559 C.139 C.61 -34.952162 -57.973733
# 1560 C.139 C.62 -34.953000 -57.972631
# 1561 C.139 C.63 -34.953827 -57.971507
# 1562 C.139 C.64 -34.954667 -57.970374
# 1563 C.139 C.65 -34.955496 -57.969250
# 1564 C.140 C.521 -34.922601 -58.015755
# 1565 C.140 C.522 -34.923428 -58.014642
# 1566 C.140 C.523 -34.924270 -58.013508
# 1567 C.140 C.524 -34.925088 -58.012391
# 1568 C.140 C.525 -34.925902 -58.011263
# 1569 C.140 C.526 -34.926799 -58.010072
# 1570 C.140 C.527 -34.927648 -58.008932
# 1571 C.140 C.528 -34.928481 -58.007784
# 1572 C.140 C.529 -34.929326 -58.006665
# 1573 C.140 C.530 -34.930148 -58.005557
# 1574 C.140 C.531 -34.930997 -58.004442
# 1575 C.140 Av.32 -34.931855 -58.003264
# 1576 C.140 C.33 -34.932718 -58.002091
# 1577 C.140 C.34 -34.933551 -58.000970
# 1578 C.140 C.35 -34.934389 -57.999846
# 1579 C.140 C.36 -34.935217 -57.998728
# 1580 C.140 C.37 -34.936042 -57.997687
# 1581 C.140 Av.38 -34.936940 -57.996436
# 1582 C.140 Calle_39 -34.937817 -57.995267
# 1583 C.140 C.40 -34.938641 -57.994149
# 1584 C.140 C.41 -34.939492 -57.993014
# 1585 C.140 Calle_42 -34.940341 -57.991885
# 1586 C.140 C.43 -34.941152 -57.990799
# 1587 C.140 Av.44 -34.941979 -57.989687
# 1588 C.140 C.45 -34.942894 -57.988448
# 1589 C.140 C.46 -34.943723 -57.987324
# 1590 C.140 C.47 -34.944565 -57.986224
# 1591 C.140 C.48 -34.944963 -57.985669
# 1592 C.140 C.49 -34.945404 -57.985076
# 1593 C.140 C.50 -34.946242 -57.983949
# 1594 C.140 Av.51 -34.946644 -57.983421
# 1595 C.140 Av.53 -34.947541 -57.982195
# 1596 C.140 C.54 -34.948000 -57.981581
# 1597 C.140 C.55 -34.948833 -57.980452
# 1598 C.140 C.56 -34.949224 -57.979916
# 1599 C.140 C.58 -34.950511 -57.978205
# 1600 C.140 C.59 -34.951329 -57.977078
# 1601 C.140 Av.60 -34.952202 -57.975925
# 1602 C.140 C.61 -34.953081 -57.974761
# 1603 C.140 C.62 -34.953915 -57.973620
# 1604 C.140 C.63 -34.954744 -57.972518
# 1605 C.140 C.64 -34.955593 -57.971400
# 1606 C.140 C.65 -34.956426 -57.970279
# 1607 C.141 C.521 -34.923505 -58.016753
# 1608 C.141 C.522 -34.924334 -58.015629
# 1609 C.141 C.523 -34.925165 -58.014486
# 1610 C.141 C.524 -34.925970 -58.013413
# 1611 C.141 C.525 -34.926819 -58.012260
# 1612 C.141 C.526 -34.927721 -58.011085
# 1613 C.141 C.527 -34.928583 -58.009937
# 1614 C.141 C.528 -34.929427 -58.008824
# 1615 C.141 C.529 -34.930243 -58.007697
# 1616 C.141 C.530 -34.931087 -58.006573
# 1617 C.141 C.531 -34.931915 -58.005454
# 1618 C.141 Av.32 -34.932768 -58.004285
# 1619 C.141 C.33 -34.933656 -58.003112
# 1620 C.141 C.34 -34.934476 -58.001988
# 1621 C.141 C.35 -34.935316 -58.000867
# 1622 C.141 C.36 -34.936152 -57.999727
# 1623 C.141 C.37 -34.936952 -57.998653
# 1624 C.141 Av.38 -34.937881 -57.997441
# 1625 C.141 Calle_39 -34.938745 -57.996272
# 1626 C.141 C.40 -34.939567 -57.995164
# 1627 C.141 C.41 -34.940411 -57.994051
# 1628 C.141 Calle_42 -34.941249 -57.992908
# 1629 C.141 C.43 -34.942069 -57.991816
# 1630 C.141 Av.44 -34.942944 -57.990631
# 1631 C.141 C.45 -34.943841 -57.989440
# 1632 C.141 C.46 -34.944650 -57.988338
# 1633 C.141 C.47 -34.945481 -57.987225
# 1634 C.141 C.48 -34.945891 -57.986679
# 1635 C.141 C.49 -34.946333 -57.986084
# 1636 C.141 C.50 -34.947149 -57.984971
# 1637 C.141 Av.51 -34.947596 -57.984379
# 1638 C.141 Av.53 -34.948478 -57.983192
# 1639 C.141 C.54 -34.948907 -57.982594
# 1640 C.141 C.55 -34.949756 -57.981478
# 1641 C.141 C.56 -34.950193 -57.980907
# 1642 C.141 C.57 -34.950604 -57.980333
# 1643 C.141 C.58 -34.951431 -57.979216
# 1644 C.141 C.59 -34.952258 -57.978092
# 1645 C.141 Av.60 -34.953133 -57.976936
# 1646 C.141 C.61 -34.954008 -57.975750
# 1647 C.141 C.62 -34.954830 -57.974653
# 1648 C.141 C.63 -34.955668 -57.973513
# 1649 C.141 C.64 -34.956514 -57.972403
# 1650 C.141 C.65 -34.957343 -57.971263
# 1651 C.142 C.521 -34.924439 -58.017779
# 1652 C.142 C.522 -34.925271 -58.016631
# 1653 C.142 C.523 -34.926098 -58.015525
# 1654 C.142 C.524 -34.926991 -58.014372
# 1655 C.142 C.525 -34.927743 -58.013283
# 1656 C.142 C.526 -34.928640 -58.012065
# 1657 C.142 C.527 -34.929502 -58.010928
# 1658 C.142 C.528 -34.930335 -58.009820
# 1659 C.142 C.529 -34.931162 -58.008718
# 1660 C.142 C.530 -34.932002 -58.007586
# 1661 C.142 C.531 -34.932827 -58.006459
# 1662 C.142 Av.32 -34.933713 -58.005314
# 1663 C.142 C.33 -34.934580 -58.004125
# 1664 C.142 C.34 -34.935394 -58.002969
# 1665 C.142 C.35 -34.936208 -58.001834
# 1666 C.142 C.36 -34.937074 -58.000734
# 1667 C.142 C.37 -34.937863 -57.999660
# 1668 C.142 Av.38 -34.938775 -57.998474
# 1669 C.142 Calle_39 -34.939659 -57.997299
# 1670 C.142 C.40 -34.940490 -57.996172
# 1671 C.142 C.41 -34.941306 -57.995078
# 1672 C.142 Calle_42 -34.942166 -57.993954
# 1673 C.142 C.43 -34.943001 -57.992805
# 1674 C.142 Av.44 -34.943836 -57.991703
# 1675 C.142 C.45 -34.944784 -57.990515
# 1676 C.142 C.46 -34.945578 -57.989364
# 1677 C.142 C.47 -34.946416 -57.988229
# 1678 C.142 C.49 -34.947258 -57.987086
# 1679 C.142 C.50 -34.948069 -57.985992
# 1680 C.142 C.54 -34.949845 -57.983629
# 1681 C.142 C.55 -34.950689 -57.982489
# 1682 C.142 C.57 -34.951502 -57.981341
# 1683 C.142 C.58 -34.952344 -57.980236
# 1684 C.142 Av.60 -34.954004 -57.977983
# 1685 C.142 C.61 -34.954925 -57.976804
# 1686 C.142 C.62 -34.955774 -57.975659
# 1687 C.142 C.63 -34.956598 -57.974538
# 1688 C.142 C.64 -34.957422 -57.973409
# 1689 C.142 C.65 -34.958260 -57.972282
# 1690 C.143 C.521 -34.925401 -58.018757
# 1691 C.143 C.522 -34.926179 -58.017679
# 1692 C.143 C.523 -34.927070 -58.016561
# 1693 C.143 C.524 -34.927919 -58.015406
# 1694 C.143 C.525 -34.928674 -58.014320
# 1695 C.143 C.526 -34.929595 -58.013143
# 1696 C.143 C.527 -34.930439 -58.012016
# 1697 C.143 C.528 -34.931275 -58.010855
# 1698 C.143 C.529 -34.932067 -58.009696
# 1699 C.143 C.530 -34.932911 -58.008588
# 1700 C.143 C.531 -34.933707 -58.007451
# 1701 C.143 Av.32 -34.934622 -58.006337
# 1702 C.143 C.33 -34.935495 -58.005161
# 1703 C.143 C.34 -34.936335 -58.004024
# 1704 C.143 C.35 -34.937184 -58.002895
# 1705 C.143 C.36 -34.938033 -58.001774
# 1706 C.143 C.37 -34.938820 -58.000725
# 1707 C.143 Av.38 -34.939737 -57.999489
# 1708 C.143 Calle_39 -34.940592 -57.998312
# 1709 C.143 C.40 -34.941453 -57.997191
# 1710 C.143 C.41 -34.942273 -57.996078
# 1711 C.143 Calle_42 -34.943093 -57.994965
# 1712 C.143 C.43 -34.943924 -57.993852
# 1713 C.143 Av.44 -34.944810 -57.992677
# 1714 C.143 C.45 -34.945670 -57.991475
# 1715 C.143 C.46 -34.946503 -57.990370
# 1716 C.143 C.47 -34.947336 -57.989243
# 1717 C.143 C.49 -34.948176 -57.988135
# 1718 C.143 C.50 -34.949007 -57.987003
# 1719 C.143 C.54 -34.950768 -57.984651
# 1720 C.143 C.55 -34.951625 -57.983495
# 1721 C.143 C.57 -34.952438 -57.982364
# 1722 C.143 C.58 -34.953268 -57.981254
# 1723 C.143 Av.60 -34.954937 -57.979004
# 1724 C.143 C.61 -34.955852 -57.977789
# 1725 C.143 C.62 -34.956692 -57.976689
# 1726 C.143 C.63 -34.957521 -57.975560
# 1727 C.143 C.64 -34.958365 -57.974439
# 1728 C.143 C.65 -34.959192 -57.973307
# Out:
# Writing Intersecciones_con_coordenadas.txt

# %%
calles = []
with open("Calles.txt") as f:
  for line in f:
    calle = line.split()
    calles.append(*calle)
print(calles)
# Out:
# ['Av.1', 'C.2', 'C.3', 'C.4', 'C.5', 'C.6', 'Av.7', 'C.8', 'C.9', 'C.10', 'C.11', 'C.12', 'Calle_14', 'C.15', 'C.16', 'C.17', 'C.18', 'Av.19', 'C.20', 'C.21', 'C.22', 'C.23', 'C.24', 'Av.25', 'C.26', 'C.27', 'Calle_28', 'C.29', 'C.30', 'Av.31', 'C.132', 'C.133', 'C.134', 'C.135', 'C.136', 'Av.137', 'C.138', 'C.139', 'C.140', 'C.141', 'C.142', 'C.143', 'C.521', 'C.522', 'C.523', 'C.524', 'C.525', 'C.526', 'C.527', 'C.528', 'C.529', 'C.530', 'C.531', 'Av.32', 'C.33', 'C.34', 'C.35', 'C.36', 'C.37', 'Av.38', 'Calle_39', 'C.40', 'C.41', 'Calle_42', 'C.43', 'Av.44', 'C.45', 'C.46', 'C.47', 'C.48', 'C.49', 'C.50', 'Av.51', 'Av.53', 'C.54', 'C.55', 'C.56', 'C.57', 'C.58', 'C.59', 'Av.60', 'C.61', 'C.62', 'C.63', 'C.64', 'C.65']

# %%
def generarIntersecciones(calles, archivo, nfilas, ncol, datos):
  n = len(calles)
  if n == nfilas + ncol:
    #Asignar numeros a las calles
    num = 0
    dicc_c = {}
    for calle in calles:
      dicc_c[calle] = num
      num += 1
    
    #Inicializamos el mapa que simule las intersecciones con puros -1  
    I = np.zeros([nfilas,ncol], int)
    I = I - 1

    #Actualizamos la matriz, poniendo los nodos de intersecciones
    with open(archivo) as f:
      for line in f:
        nodo, fila, columna, y, x = [elem for elem in line.split()]
        I[dicc_c[fila], dicc_c[columna] - nfilas] = int(nodo)
        datos[int(nodo)] = (float(x), float(y))

  return I

# %%
datos = {}
I = generarIntersecciones(calles, "Intersecciones_con_coordenadas.txt", 42, 44, datos)
print(I)
print(datos)
# Out:
# [[   0    1   -1 ...   35   36   37]
#  [  38   39   -1 ...   74   75   76]
#  [  77   78   79 ...  118  119  120]
#  ...
#  [1607 1608 1609 ... 1648 1649 1650]
#  [1651 1652 1653 ... 1687 1688 1689]
#  [1690 1691 1692 ... 1726 1727 1728]]
# ...

# %%
def generarListaAdyacencia(I, datos):
  G = []
  nfilas, ncol = np.shape(I)
  
  #Agregar las adyacencias de cada nodo
  for i in range(nfilas):
    for j in range(ncol):
      if I[i,j] > -1:
        aux = []
        x1, y1 = datos[I[i,j]]
        #arriba
        if (i > 0) and (I[i-1, j] > -1):
          x2, y2 = datos[I[i-1, j]]
          y1 = int(y1*1000000)
          y2 = int(y2*1000000)
          peso = abs(y2-y1)
          if peso > 2500:
            peso = random.randint(2500, 2600)
          aux.append((I[i-1, j], peso))
        #izquierda
        if (j > 0) and (I[i, j-1] > -1):
          x2, y2 = datos[I[i, j-1]]
          x1 = int(x1*1000000)
          x2 = int(x2*1000000)
          peso = abs(x2-x1)
          if peso > 2500:
            peso = random.randint(2500, 2600)
          aux.append((I[i, j-1], peso))
        #derecha (bug)
        if (j < ncol-1) and (I[i, j+1] > -1):
          x2, y2 = datos[I[i, j+1]]
          x1 = int(x1*1000000)
          x2 = int(x2*1000000)
          peso = abs(x1-x2)
          if peso > 2500:
            peso = random.randint(2500, 2600)
          aux.append((I[i, j+1], peso))
        #abajo (bug)
        if (i < nfilas-1) and (I[i+1, j] > -1):
          x2, y2 = datos[I[i+1, j]]
          y1 = int(y1*1000000)
          y2 = int(y2*1000000)
          peso = abs(y1-y2)
          if peso > 2500:
            peso = random.randint(2500, 2600)
          aux.append((I[i+1, j], peso))
        G.append(aux)

  #Guardar en un archivo
  cont = 0
  with open("Lista_Adyacencia_Generado.txt", 'w') as archivo:
    for lista in G:
      for num in lista:
        archivo.write(str(num) + " ")
      archivo.write("\n")

  return G

# %%
Output = generarListaAdyacencia(I, datos)
print(Output)
# Out:
# [[(1, 2357), (38, 1414)], [(0, 2357), (39, 551)], [(3, 1040), (40, 645)], [(2, 1040), (4, 2502), (41, 689)], [(3, 1052), (5, 2585), (42, 669)], [(4, 1062), (6, 2558), (43, 674)], [(5, 1068), (7, 2558), (44, 840)], [(6, 1159), (8, 2573), (45, 871)], [(7, 1121), (9, 2558), (46, 909)], [(8, 1164), (10, 2526), (47, 919)], [(9, 1094), (11, 2583), (48, 893)], [(10, 1111), (49, 907)], [(13, 1137), (51, 930)], [(12, 1137), (14, 2502), (52, 868)], [(13, 1168), (15, 2557), (53, 979)], [(14, 1135), (16, 2519), (54, 944)], [(15, 1104), (17, 2533), (55, 970)], [(16, 1095), (18, 2581), (56, 1073)], [(17, 1314), (19, 2600), (57, 912)], [(18, 1078), (20, 2555), (58, 1062)], [(19, 896), (21, 2569), (59, 910)], [(20, 815), (22, 2547), (60, 928)], [(21, 778), (23, 2547), (61, 893)], [(22, 767), (24, 2538), (62, 930)], [(23, 660), (25, 2522), (63, 961)], [(24, 1255), (26, 2508), (64, 974)], [(25, 655), (27, 2594), (65, 928)], [(26, 700), (28, 2537), (66, 961)], [(27, 846), (29, 2527), (67, 941)], [(28, 
# ...

# %% [markdown]
# #MARX

# %%
class Perlin:
    def __init__(self):
        self.gradients = []
        self.lowerBound = 0


    def valueAt(self, t):
        if(t<self.lowerBound):
            print("ERROR: Input parameter out of bounds!")
            return
        # Add to gradients until it covers t
        while t >= len(self.gradients)-1+self.lowerBound:
            self.gradients.append(random.uniform(-1, 1))

        discarded = int(self.lowerBound) # getting number of gradients that have been discarded
        # Compute products between surrounding gradients and distances from them
        d1 = (t-t//1)
        d2 = d1-1
        a1 = self.gradients[(int)(t//1)-discarded]*d1
        a2 = self.gradients[(int)(t//1+1)-discarded]*d2

        amt = self.__ease(d1)

        return self.__lerp(a1,a2,amt)

    def discard(self, amount):
        gradientsToDiscard = int(amount+self.lowerBound%1)
        self.gradients = self.gradients[gradientsToDiscard:]
        self.lowerBound += amount

    def __ease(self, x):
        return 6*x**5-15*x**4+10*x**3


    def __lerp(self, start, stop, amt):
        return amt*(stop-start)+start

# %%
import random
import statistics
import matplotlib.pyplot as plt

noise=Perlin()
time=[i*0.01 for i in range(1729)]
values=[noise.valueAt(i)*1000 for i in time]

# %%
positivos=filter(lambda x:x>0,values)
negativos=filter(lambda x:x<0,values)
criterio3=statistics.mean(positivos)
criterio4=statistics.mean(negativos)

# %%
datos = {}
I = generarIntersecciones(calles, "Intersecciones_con_coordenadas.txt", 42, 44, datos)
print(I)
print(datos)
# Out:
# [[   0    1   -1 ...   35   36   37]
#  [  38   39   -1 ...   74   75   76]
#  [  77   78   79 ...  118  119  120]
#  ...
#  [1607 1608 1609 ... 1648 1649 1650]
#  [1651 1652 1653 ... 1687 1688 1689]
#  [1690 1691 1692 ... 1726 1727 1728]]
# ...

# %%
def generarListaAdyacencia2(I, datos):
  G = []
  nfilas, ncol = np.shape(I)
  #Agregar las adyacencias de cada nodo
  for i in range(nfilas):
    for j in range(ncol):
      if I[i,j] > -1:
        aux = []
        x1, y1 = datos[I[i,j]]
        #arriba
        if (i > 0) and (I[i-1, j] > -1):
          x2, y2 = datos[I[i-1, j]]
          peso1 = abs((y2-y1)*100000)
          traficcValue=values[i+1]
          peso2=0.3
          if traficcValue>0 and traficcValue<criterio3:
            peso2=0.7
          if traficcValue>0 and traficcValue>criterio3:
            peso2=1.5
          if traficcValue<0 and traficcValue<criterio4:
            peso2=0.7
          if traficcValue<0 and traficcValue>criterio4:
            peso2=1.5
          peso=peso1*peso2
          aux.append((I[i-1, j], peso))
        #izquierda
        if (j > 0) and (I[i, j-1] > -1):
          x2, y2 = datos[I[i, j-1]]
          peso1 = abs((x2-x1)*1000)
          traficcValue=values[i+1]
          peso2=0.3
          if traficcValue>0 and traficcValue<criterio3:
            peso2=0.7
          if traficcValue>0 and traficcValue>criterio3:
            peso2=1.5
          if traficcValue<0 and traficcValue<criterio4:
            peso2=0.7
          if traficcValue<0 and traficcValue>criterio4:
            peso2=1.5
          peso=peso1*peso2
          aux.append((I[i, j-1], peso))
        #derecha (bug)
        if (j < ncol-1) and (I[i, j+1] > -1):
          x2, y2 = datos[I[i, j+1]]
          peso1 = abs((x1-x2)*1000)
          traficcValue=values[i+1]
          peso2=0.3
          if traficcValue>0 and traficcValue<criterio3:
            peso2=0.7
          if traficcValue>0 and traficcValue>criterio3:
            peso2=1.5
          if traficcValue<0 and traficcValue<criterio4:
            peso2=0.7
          if traficcValue<0 and traficcValue>criterio4:
            peso2=1.5
          peso=peso1*peso2
          aux.append((I[i, j+1], peso))
        #abajo (bug)
        if (i < nfilas-1) and (I[i+1, j] > -1):
          x2, y2 = datos[I[i+1, j]]
          peso1 = abs((y1-y2)*100000)
          traficcValue=values[i+1]
          peso2=0.3
          if traficcValue>0 and traficcValue<criterio3:
            peso2=0.7
          if traficcValue>0 and traficcValue>criterio3:
            peso2=1.5
          if traficcValue<0 and traficcValue<criterio4:
            peso2=0.7
          if traficcValue<0 and traficcValue>criterio4:
            peso2=1.5
          peso=peso1*peso2
          aux.append((I[i+1, j], peso))
        G.append(aux)

  #Guardar en un archivo
  cont = 0
  with open("Lista_Adyacencia_Generado2.txt", 'w') as archivo:
    for lista in G:
      for num in lista:
        archivo.write(str(num) + " ")
      archivo.write("\n")

  return G

# %%
a = generarListaAdyacencia2(I, datos)
print(a)
# Out:
# [[(1, 3.535500000005243), (38, 212.10000000060347)], [(0, 3.535500000005243), (39, 82.65000000022837)], [(3, 1.5600000000048908), (40, 96.75000000086698)], [(2, 1.5600000000048908), (4, 1.5779999999914196), (41, 103.35000000019079)], [(3, 1.5779999999914196), (5, 1.593000000006839), (42, 100.35000000030436)], [(4, 1.593000000006839), (6, 1.6019999999947743), (43, 101.09999999947661)], [(5, 1.6019999999947743), (7, 1.7385000000018636), (44, 125.99999999949318)], [(6, 1.7385000000018636), (8, 1.6814999999965607), (45, 130.65000000054283)], [(7, 1.6814999999965607), (9, 1.7460000000042442), (46, 136.3500000000073)], [(8, 1.7460000000042442), (10, 1.6410000000028901), (47, 137.85000000048342)], [(9, 1.6410000000028901), (11, 1.6664999999917995), (48, 133.94999999967183)], [(10, 1.6664999999917995), (49, 136.0499999996989)], [(13, 1.7054999999999154), (51, 139.50000000058083)], [(12, 1.7054999999999154), (14, 1.7519999999997538), (52, 130.20000000061316)], [(13, 1.7519999999997538), (15, 
# ...
